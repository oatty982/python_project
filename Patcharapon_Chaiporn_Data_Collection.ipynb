# %% [markdown]
# # Data Collection: มาเก็บรวบรวมข้อมูลจากแหล่งต่าง ๆ (DB & REST API)

# %% [markdown]
# ## Install PyMySQL
# ซึ่งเป็น package สำหรับเชื่อมต่อ MySQL database

# %%
! pip install pymysql
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pymysql
#   Downloading PyMySQL-1.0.2-py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 1.5 MB/s
# Installing collected packages: pymysql
# Successfully installed pymysql-1.0.2

# %% [markdown]
# ขึ้นตอนแรกสำหรับการต่อ database คือการสร้าง connection ซึ่งต้องอาศัย config ต่าง ๆ เช่น Host (IP address), Username, Password ในการเชื่อมต่อ เป็นต้น บางอย่างก็ต้องเก็บเป็นความลับ

# %% [markdown]
# ## Config DB credential: การใช้ config สำหรับเชื่อต่อ database
# ಥ_ಥ  คำเตือน: Cell ด้านล่างนี้เป็นความลับสุดยอด เขียนขึ้นมาเพื่อให้เห็นวิธีการในการเชื่อมต่อ database เท่านั้น **ห้ามเอา "plain text"แบบนี้ไปใช้ในชีวิตจริง**
#
# มีข้อปฏิบัติในการเก็บรักษาไฟล์ที่เป็นความลับ (secret) ดังนี้
# *   **ห้าม**เขียน credential (ความลับ) ลงมาใน code ตรง ๆ
# *   **ห้าม** commit credential ในโค้ดลง Git เด็ดขาด
# *   credential ควรเป็น environment variable / ไฟล์ .env / หรือ config file ที่เหมาะสม
# *   **ห้าม** commit config file หรือ .env ไฟล์ดังกล่าวที่มี key หรือ password ขึ้น Git ด้วย
# *   ควรใช้ระบบ secret management เพื่อเก็บ credential อย่างปลอดภัย เช่น Vault หรือ Secret Manager ของ Cloud แต่ละที่
# *   การขัดต่อคำแนะนำตามที่กล่าวมาถือว่าไม่ควรทำอย่างยิ่ง
#
# ༼ つ ◕_◕ ༽つ  **Bonus**: ในท้าย workshop จะมีการพูดถึงการเก็บพาสเวิร์ดใน .env ซึ่งใช้กันทั่วไป และใช้งานกับ python ด้วย package python-dotenv

# %% [markdown]
# สามารถดู password ของ database ได้ที่: https://school.datath.com/courses/road-to-data-engineer-2/contents/611fc12108727

# %% [markdown]
# MYSQL_HOST = '34.136.184.58'
#
# MYSQL_PORT = 3306
#
# MYSQL_USER = 'r2de2'
#
# MYSQL_PASSWORD = 'I_Love_Data_Engineer'
#
# MYSQL_DB = 'r2de2'
#
# MYSQL_CHARSET = 'utf8mb4'

# %%
# TODO: ใส่ database credential จากลิงค์ database ด้านบน (เพื่อการเรียนรู้)
import os

class Config:
  MYSQL_HOST = '34.136.184.58'
  MYSQL_PORT = 3306              # default สำหรับ port MySQL
  MYSQL_USER = 'r2de2'
  MYSQL_PASSWORD = 'I_Love_Data_Engineer'
  MYSQL_DB = 'r2de2'
  MYSQL_CHARSET = 'utf8mb4'

# %%
# ทดลอง print จาก config
print(Config.MYSQL_PORT)
# Out:
# 3306

# %% [markdown]
# ## Connect to DB
# หลังจากที่มี Credential ของ database แล้วก็สร้าง connection โดยการ connect ไปที่ DB ด้วย Config ของเรา

# %%
import pymysql

# Connect to the database
connection = pymysql.connect(host=Config.MYSQL_HOST,
                             port=Config.MYSQL_PORT,
                             user=Config.MYSQL_USER,
                             password=Config.MYSQL_PASSWORD,
                             db=Config.MYSQL_DB,
                             charset=Config.MYSQL_CHARSET,
                             cursorclass=pymysql.cursors.DictCursor)

# %% [markdown]
# cursors เป็น object ของ database ที่เอาไว้ใช้ในการเข้าถึง data การใช้งานจึงเป็นไปตามการออกแบบของแต่ละ database  ในกรณีนี้ก็จะใช้อ้างอิงตาม documentation ของ PyMySQL แล้วสามารถอ้างอิง                                                                                                                                                                                                                                                                                            โค้ดตามนั้นได้เลย https://pymysql.readthedocs.io/en/latest/user/examples.html

# %%
connection

# %% [markdown]
# ตัวแปร connection นี้ เราได้ connect ต่อเข้ากับ database เอาไว้แล้ว
# ## List Tables
# เรามาลองดูกันว่ามี table อะไรในนั้นบ้าง

# %%
# list all tables ด้วย SQL คำสั่ง show tables;
cursor = connection.cursor()
cursor.execute("show tables;")
tables = cursor.fetchall()
cursor.close()
print(tables)
# Out:
# [{'Tables_in_r2de2': 'audible_data'}, {'Tables_in_r2de2': 'audible_transaction'}]

# %% [markdown]
# `show tables` เป็น SQL ในการลิสต์ table ออกมา
#
# จากโค้ดตัวอย่างด้านบนจะเห็นได้ว่า การคิวรี่ database ทุกครั้ง เราจะต้องสร้าง `cursor` ขึ้นมาเพื่อ query SQL นั้น แล้วก็ปิด cursor ทุกครั้งหลังจบ
#
# ดังนั้น จึงนิยมใช้คำสั่ง `with` ในการจัดการสร้าง cursor ขึ้นมา เมื่อจบคำสั่ง cursor จะถูก close ไปเองโดยอัตโนมัติเมื่อออกนอก scope ของ `with`

# %% [markdown]
# ## Query Table

# %% [markdown]
# การใช้ `with connection.cursor() as cursor:` จะจัดการ scope ของการเรียกใช้งาน cursor ให้  ในที่นี้ถือว่าได้สร้างตัวแปร cursor แล้วในคำสั่ง with และ ไม่ต้องใช้ cursor.close()

# %%
# ใข้ with statement แทน cursor.close()
# TODO: มาลองเขียน SQL Query ข้อมูลจาก table audible_data ดูกัน

with connection.cursor() as cursor:
  cursor.execute("SELECT * FROM audible_data;")
  result = cursor.fetchall()
  # query ข้อมูลจาก table audible_data

print("number of rows: ", len(result))
# Out:
# number of rows:  2269

# %%
# สามารถดูผลลัพธ์ที่อ่าน result มาได้ ⁀⊙﹏☉⁀
result
# Out:
# [{'Book_ID': 1,
#   'Book Title': 'Bamboozled by Jesus',
#   'Book Subtitle': 'How God Tricked Me into the Life of My Dreams',
#   'Book Author': 'Yvonne Orji',
#   'Book Narrator': 'Yvonne Orji',
#   'Audio Runtime': '6 hrs and 31 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Biographies & Memoirs',
#   'Rating': '5',
#   'Total No. of Ratings': 47,
#   'Price': '$29.65 '},
#  {'Book_ID': 2,
#   'Book Title': 'Sixth Realm Part 1',
#   'Book Subtitle': 'A LitRPG Fantasy Series (The Ten Realms, Book 6)',
#   'Book Author': 'Michael Chatfield',
#   'Book Narrator': 'Neil Hellegers',
#   'Audio Runtime': '13 hrs and 33 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Science Fiction & Fantasy',
#   'Rating': '4.5',
#   'Total No. of Ratings': 98,
#   'Price': '$24.95 '},
#  {'Book_ID': 3,
#   'Book Title': 'Go Tell the Bees That I Am Gone',
#   'Book Subtitle': 'Outlander, Book 9',
#   'Book Author': 'Diana Gabaldon',
#   'Book Narrator': 'Davina Porter',
#   'Audio Runtime': '27 hrs and 30 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Science Fiction & Fantasy',
#   'Rating': None,
#   'Total No. of Ratings': None,
#   'Price': '$41.99 '},
#  {'Book_ID': 4,
#   'Book Title': 'How the Word Is Passed',
#   'Book Subtitle': 'A Reckoning with the History of Slavery Across America',
#   'Book Author': 'Clint Smith',
#   'Book Narrator': 'Clint Smith',
#   'Audio Runtime': '10 hrs and 7 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'History',
#   'Rating': None,
#   'Total No. of Ratings': None,
#   'Price': '$29.65 '},
#  {'Book_ID': 5,
#   'Book Title': 'The Devil May Dance',
#   'Book Subtitle': 'A Novel',
#   'Book Author': 'Jake Tapper',
#   'Book Narrator': 'Rob Shapiro',
#   'Audio Runtime': '10 hrs and 12 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Mystery, Thriller & Suspense',
#   'Rating': '4.5',
#   'Total No. of Ratings': 108,
#   'Price': '$29.65 '},
#  {'Book_ID': 6,
#   'Book Title': 'Shadow Storm',
#   'Book Subtitle': 'Shadow Rider, Book 6',
#   'Book Author': 'Christine Feehan',
#   'Book Narrator': 'Jim Frangione',
#   'Audio Runtime': '13 hrs and 42 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Mystery, Thriller & Suspense',
#   'Rating': '4.8',
#   'Total No. of Ratings': 124,
#   'Price': '$31.49 '},
#  {'Book_ID': 7,
#   'Book Title': 'American Marxism',
#   'Book Subtitle': None,
#   'Book Author': 'Mark R. Levin',
#   'Book Narrator': 'Jeremy Lowell',
#   'Audio Runtime': '6 hrs and 30 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Politics & Social Sciences',
#   'Rating': None,
#   'Total No. of Ratings': None,
#   'Price': '$18.89 '},
#  {'Book_ID': 8,
#   'Book Title': 'Mercy',
#   'Book Subtitle': None,
#   'Book Author': 'David Baldacci',
#   'Book Narrator': None,
#   'Audio Runtime': '13 hrs',
#   'Audiobook_Type': None,
#   'Categories': None,
#   'Rating': 'Not rated yet',
#   'Total No. of Ratings': None,
#   'Price': '$30.79 '},
#  {'Book_ID': 9,
#   'Book Title': 'Dream Spinner',
#   'Book Subtitle': None,
#   'Book Author': 'Kristen Ashley',
#   'Book Narrator': 'Susannah Jones',
#   'Audio Runtime': '12 hrs and 45 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Romance',
#   'Rating': '4.6',
#   'Total No. of Ratings': 101,
#   'Price': '$29.65 '},
#  {'Book_ID': 10,
#   'Book Title': 'Fortune Funhouse',
#   'Book Subtitle': 'Miss Fortune Mysteries, Book 19',
#   'Book Author': 'Jana DeLeon',
#   'Book Narrator': 'Cassandra Campbell',
#   'Audio Runtime': '9 hrs and 21 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Mystery, Thriller & Suspense',
#   'Rating': '4.9',
#   'Total No. of Ratings': 414,
#   'Price': '$19.95 '},
#  {'Book_ID': 11,
#   'Book Title': 'Godblight',
#   'Book Subtitle': 'Dark Imperium: Warhammer 40,000, Book 3',
#   'Book Author': 'Guy Haley',
#   'Book Narrator': 'John Banks',
#   'Audio Runtime': '13 hrs and 2 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Science Fiction & Fantasy',
#   'Rating': '4.7',
#   'Total No. of Ratings': 3,
#   'Price': '$32.71 '},
#  {'Book_ID': 12,
#   'Book Title': 'The Missing Sister',
#   'Book Subtitle': None,
#   'Book Author': 'Lucinda Riley',
#   'Book Narrator': 'Caroline Lennon',
#   'Audio Runtime': '23 hrs and 48 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Literature & Fiction',
#   'Rating': '4.3',
#   'Total No. of Ratings': 3,
#   'Price': '$32.71 '},
#  {'Book_ID': 13,
#   'Book Title': 'The Bomber Mafia',
#   'Book Subtitle': 'A Dream, a Temptation, and the Longest Night of the Second World War',
#   'Book Author': 'Malcolm Gladwell',
#   'Book Narrator': 'Malcolm Gladwell',
#   'Audio Runtime': '5 hrs and 14 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'History',
#   'Rating': '4.7',
#   'Total No. of Ratings': 1923,
#   'Price': '$22.40 '},
#  {'Book_ID': 14,
#   'Book Title': 'Yearbook',
#   'Book Subtitle': None,
#   'Book Author': 'Seth Rogen',
#   'Book Narrator': 'Seth Rogen',
#   'Audio Runtime': '6 hrs and 13 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Biographies & Memoirs',
#   'Rating': '4.8',
#   'Total No. of Ratings': 1614,
#   'Price': '$28.00 '},
#  {'Book_ID': 15,
#   'Book Title': 'Unsettled',
#   'Book Subtitle': "What Climate Science Tells Us, What It Doesn't, and Why It Matters",
#   'Book Author': 'Steven E. Koonin',
#   'Book Narrator': 'Jay Aaseng',
#   'Audio Runtime': '7 hrs and 14 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Politics & Social Sciences',
#   'Rating': '4.9',
#   'Total No. of Ratings': 63,
#   'Price': '$15.40 '},
#  {'Book_ID': 16,
#   'Book Title': 'Legacy',
#   'Book Subtitle': 'A Novel',
#   'Book Author': 'Nora Roberts',
#   'Book Narrator': 'January LaVoy',
#   'Audio Runtime': '14 hrs and 57 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Literature & Fiction',
#   'Rating': '4.8',
#   'Total No. of Ratings': 329,
#   'Price': '$31.18 '},
#  {'Book_ID': 17,
#   'Book Title': 'How to Do the Work',
#   'Book Subtitle': 'Recognize Your Patterns, Heal from Your Past, and Create Your Self',
#   'Book Author': 'Dr. Nicole LePera',
#   'Book Narrator': 'Courtney Patterson',
#   'Audio Runtime': '9 hrs and 42 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Health & Wellness',
#   'Rating': '4.5',
#   'Total No. of Ratings': 46,
#   'Price': '$30.79 '},
#  {'Book_ID': 18,
#   'Book Title': 'Breakaway',
#   'Book Subtitle': 'Expeditionary Force, Book 12',
#   'Book Author': 'Craig Alanson',
#   'Book Narrator': 'R.C. Bray',
#   'Audio Runtime': '19 hrs and 22 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Science Fiction & Fantasy',
#   'Rating': None,
#   'Total No. of Ratings': None,
#   'Price': '$59.99 '},
#  {'Book_ID': 19,
#   'Book Title': 'The 1619 Project',
#   'Book Subtitle': 'A New Origin Story',
#   'Book Author': 'Nikole Hannah-Jones',
#   'Book Narrator': None,
#   'Audio Runtime': '8 hrs',
#   'Audiobook_Type': None,
#   'Categories': None,
#   'Rating': 'Not rated yet',
#   'Total No. of Ratings': None,
#   'Price': '$28.00 '},
#  {'Book_ID': 20,
#   'Book Title': 'Greenlights',
#   'Book Subtitle': None,
#   'Book Author': 'Matthew McConaughey',
#   'Book Narrator': 'Matthew McConaughey',
#   'Audio Runtime': '6 hrs and 42 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Biographies & Memoirs',
#   'Rating': '4.9',
#   'Total No. of Ratings': 78263,
#   'Price': '$28.00 '},
#  {'Book_ID': 21,
#   'Book Title': 'Something Wicked This Way Comes',
#   'Book Subtitle': None,
#   'Book Author': 'Ray Bradbury',
#   'Book Narrator': 'Christian Rummel',
#   'Audio Runtime': '9 hrs and 5 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Literature & Fiction',
#   'Rating': '4.2',
#   'Total No. of Ratings': 4593,
#   'Price': '$19.95 '},
#  {'Book_ID': 22,
#   'Book Title': 'The Saboteurs',
#   'Book Subtitle': 'An Isaac Bell Adventure, Book 12',
#   'Book Author': 'Clive Cussler',
#   'Book Narrator': 'Scott Brick',
#   'Audio Runtime': '11 hrs and 14 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Literature & Fiction',
#   'Rating': '4.8',
#   'Total No. of Ratings': 62,
#   'Price': '$31.50 '},
#  {'Book_ID': 23,
#   'Book Title': 'What Happened to You?',
#   'Book Subtitle': 'Conversations on Trauma, Resilience, and Healing',
#   'Book Author': 'Oprah Winfrey',
#   'Book Narrator': 'Bruce D. Perry',
#   'Audio Runtime': '8 hrs and 27 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Health & Wellness',
#   'Rating': '4.9',
#   'Total No. of Ratings': 2048,
#   'Price': '$20.99 '},
#  {'Book_ID': 24,
#   'Book Title': 'The Last Thing He Told Me',
#   'Book Subtitle': 'A Novel',
#   'Book Author': 'Laura Dave',
#   'Book Narrator': 'Rebecca Lowman',
#   'Audio Runtime': '8 hrs and 49 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Literature & Fiction',
#   'Rating': '4.5',
#   'Total No. of Ratings': 4460,
#   'Price': '$22.67 '},
#  {'Book_ID': 25,
#   'Book Title': 'Chasing Fire',
#   'Book Subtitle': None,
#   'Book Author': 'Nora Roberts',
#   'Book Narrator': 'Rebecca Lowman',
#   'Audio Runtime': '15 hrs and 10 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Literature & Fiction',
#   'Rating': '4.4',
#   'Total No. of Ratings': 6632,
#   'Price': '$29.99 '},
#  {'Book_ID': 26,
#   'Book Title': 'Project Hail Mary',
#   'Book Subtitle': None,
#   'Book Author': 'Andy Weir',
#   'Book Narrator': 'Ray Porter',
#   'Audio Runtime': '16 hrs and 10 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Science Fiction & Fantasy',
#   'Rating': '4.9',
#   'Total No. of Ratings': 17208,
#   'Price': '$29.95 '},
#  {'Book_ID': 27,
#   'Book Title': "The Dungeon Anarchist's Cookbook",
#   'Book Subtitle': 'Dungeon Crawler Carl, Book 3',
#   'Book Author': 'Matt Dinniman',
#   'Book Narrator': 'Jeff Hays The Critical Drinker',
#   'Audio Runtime': '16 hrs and 54 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Literature & Fiction',
#   'Rating': '4.9',
#   'Total No. of Ratings': 503,
#   'Price': '$24.95 '},
#  {'Book_ID': 28,
#   'Book Title': 'The Enemy Within',
#   'Book Subtitle': 'How a Totalitarian Movement Is Destroying America',
#   'Book Author': 'David Horowitz',
#   'Book Narrator': 'Rick Adamson',
#   'Audio Runtime': '7 hrs and 47 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Politics & Social Sciences',
#   'Rating': '4.9',
#   'Total No. of Ratings': 50,
#   'Price': '$17.49 '},
#  {'Book_ID': 29,
#   'Book Title': 'Amazon Unbound',
#   'Book Subtitle': 'Jeff Bezos and the Invention of a Global Empire',
#   'Book Author': 'Brad Stone',
#   'Book Narrator': 'Pete Larkin',
#   'Audio Runtime': '16 hrs and 33 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Biographies & Memoirs',
#   'Rating': '4.5',
#   'Total No. of Ratings': 77,
#   'Price': '$28.34 '},
#  {'Book_ID': 30,
#   'Book Title': 'The Four Agreements',
#   'Book Subtitle': None,
#   'Book Author': 'don Miguel Ruiz',
#   'Book Narrator': 'Peter Coyote',
#   'Audio Runtime': '2 hrs and 31 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Relationships, Parenting & Personal Development',
#   'Rating': '4.7',
#   'Total No. of Ratings': 35939,
#   'Price': '$14.95 '},
#  {'Book_ID': 31,
#   'Book Title': 'Sapiens',
#   'Book Subtitle': 'A Brief History of Humankind',
#   'Book Author': 'Yuval Noah Harari',
#   'Book Narrator': 'Derek Perkins',
#   'Audio Runtime': '15 hrs and 17 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Politics & Social Sciences',
#   'Rating': '4.7',
#   'Total No. of Ratings': 43410,
#   'Price': '$34.22 '},
#  {'Book_ID': 32,
#   'Book Title': 'Never Split the Difference',
#   'Book Subtitle': 'Negotiating as if Your Life Depended on It',
#   'Book Author': 'Chris Voss',
#   'Book Narrator': 'Michael Kramer',
#   'Audio Runtime': '8 hrs and 7 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Business & Careers',
#   'Rating': '4.8',
#   'Total No. of Ratings': 50427,
#   'Price': '$27.37 '},
#  {'Book_ID': 33,
#   'Book Title': 'Atomic Habits',
#   'Book Subtitle': 'An Easy & Proven Way to Build Good Habits & Break Bad Ones',
#   'Book Author': 'James Clear',
#   'Book Narrator': 'James Clear',
#   'Audio Runtime': '5 hrs and 35 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Business & Careers',
#   'Rating': '4.8',
#   'Total No. of Ratings': 63238,
#   'Price': '$28.00 '},
#  {'Book_ID': 34,
#   'Book Title': "The Devil's Highway",
#   'Book Subtitle': 'A True Story',
#   'Book Author': 'Luis Alberto Urrea',
#   'Book Narrator': 'Luis Alberto Urrea',
#   'Audio Runtime': '8 hrs and 53 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'History',
#   'Rating': '4.5',
#   'Total No. of Ratings': 925,
#   'Price': '$22.80 '},
#  {'Book_ID': 35,
#   'Book Title': 'Animal Farm',
#   'Book Subtitle': None,
#   'Book Author': 'George Orwell',
#   'Book Narrator': 'Benjamin May',
#   'Audio Runtime': '3 hrs and 25 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Literature & Fiction',
#   'Rating': '4.7',
#   'Total No. of Ratings': 3,
#   'Price': '$0.94 '},
#  {'Book_ID': 36,
#   'Book Title': 'The Subtle Art of Not Giving a F*ck',
#   'Book Subtitle': 'A Counterintuitive Approach to Living a Good Life',
#   'Book Author': 'Mark Manson',
#   'Book Narrator': 'Roger Wayne',
#   'Audio Runtime': '5 hrs and 17 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Relationships, Parenting & Personal Development',
#   'Rating': '4.5',
#   'Total No. of Ratings': 143539,
#   'Price': '$23.95 '},
#  {'Book_ID': 37,
#   'Book Title': 'Captivate',
#   'Book Subtitle': 'The Science of Succeeding with People',
#   'Book Author': 'Vanessa Van Edwards',
#   'Book Narrator': 'Vanessa Van Edwards',
#   'Audio Runtime': '7 hrs and 28 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Business & Careers',
#   'Rating': '4.6',
#   'Total No. of Ratings': 3087,
#   'Price': '$28.00 '},
#  {'Book_ID': 38,
#   'Book Title': 'The Marriage',
#   'Book Subtitle': None,
#   'Book Author': 'K. L. Slater',
#   'Book Narrator': 'Lucy Price-Lewis',
#   'Audio Runtime': '9 hrs and 7 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Mystery, Thriller & Suspense',
#   'Rating': '4.2',
#   'Total No. of Ratings': 37,
#   'Price': '$16.35 '},
#  {'Book_ID': 39,
#   'Book Title': "Howl's Moving Castle",
#   'Book Subtitle': None,
#   'Book Author': 'Diana Wynne Jones',
#   'Book Narrator': 'Jenny Sterlin',
#   'Audio Runtime': '8 hrs and 34 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': "Children's Audiobooks",
#   'Rating': '4.7',
#   'Total No. of Ratings': 8923,
#   'Price': '$31.47 '},
#  {'Book_ID': 40,
#   'Book Title': 'Killers of the Flower Moon',
#   'Book Subtitle': 'The Osage Murders and the Birth of the FBI',
#   'Book Author': 'David Grann',
#   'Book Narrator': 'Will Patton',
#   'Audio Runtime': '9 hrs and 4 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Biographies & Memoirs',
#   'Rating': '4.4',
#   'Total No. of Ratings': 12640,
#   'Price': '$27.95 '},
#  {'Book_ID': 41,
#   'Book Title': 'A Land So Strange',
#   'Book Subtitle': 'The Epic Journey of Cabeza de Vaca',
#   'Book Author': 'Andres Resendez',
#   'Book Narrator': 'Jonathan Davis',
#   'Audio Runtime': '7 hrs and 13 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Biographies & Memoirs',
#   'Rating': '4.6',
#   'Total No. of Ratings': 796,
#   'Price': '$19.95 '},
#  {'Book_ID': 42,
#   'Book Title': 'Rich Dad Poor Dad',
#   'Book Subtitle': 'What the Rich Teach Their Kids About Money - That the Poor and Middle Class Do Not!',
#   'Book Author': 'Robert T. Kiyosaki',
#   'Book Narrator': 'Tim Wheeler',
#   'Audio Runtime': '6 hrs and 9 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Money & Finance',
#   'Rating': '4.8',
#   'Total No. of Ratings': 65801,
#   'Price': '$24.99 '},
#  {'Book_ID': 43,
#   'Book Title': 'Crying in H Mart',
#   'Book Subtitle': 'A Memoir',
#   'Book Author': 'Michelle Zauner',
#   'Book Narrator': 'Michelle Zauner',
#   'Audio Runtime': '7 hrs and 23 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Biographies & Memoirs',
#   'Rating': '4.9',
#   'Total No. of Ratings': 362,
#   'Price': '$28.00 '},
#  {'Book_ID': 44,
#   'Book Title': 'Shadow and Bone',
#   'Book Subtitle': None,
#   'Book Author': 'Leigh Bardugo',
#   'Book Narrator': 'Lauren Fortgang',
#   'Audio Runtime': '9 hrs and 21 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Teen',
#   'Rating': '4.4',
#   'Total No. of Ratings': 8194,
#   'Price': '$19.95 '},
#  {'Book_ID': 45,
#   'Book Title': 'Afterlife',
#   'Book Subtitle': 'Crossbreed Series, Book 10',
#   'Book Author': 'Dannika Dark',
#   'Book Narrator': 'Nicole Poole',
#   'Audio Runtime': '12 hrs',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Romance',
#   'Rating': '4.9',
#   'Total No. of Ratings': 259,
#   'Price': '$17.49 '},
#  {'Book_ID': 46,
#   'Book Title': 'How to Win Friends & Influence People',
#   'Book Subtitle': None,
#   'Book Author': 'Dale Carnegie',
#   'Book Narrator': 'Andrew MacMillan',
#   'Audio Runtime': '7 hrs and 15 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Relationships, Parenting & Personal Development',
#   'Rating': '4.7',
#   'Total No. of Ratings': 82649,
#   'Price': '$31.93 '},
#  {'Book_ID': 47,
#   'Book Title': 'The Plot',
#   'Book Subtitle': None,
#   'Book Author': 'Jean Hanff Korelitz',
#   'Book Narrator': 'Kirby Heyborne',
#   'Audio Runtime': '10 hrs and 43 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Mystery, Thriller & Suspense',
#   'Rating': '4',
#   'Total No. of Ratings': 181,
#   'Price': '$27.99 '},
#  {'Book_ID': 48,
#   'Book Title': 'Never Go Back',
#   'Book Subtitle': 'Jack Reacher, Book 18',
#   'Book Author': 'Lee Child',
#   'Book Narrator': 'Dick Hill',
#   'Audio Runtime': '13 hrs and 44 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Mystery, Thriller & Suspense',
#   'Rating': '4.4',
#   'Total No. of Ratings': 7961,
#   'Price': '$31.50 '},
#  {'Book_ID': 49,
#   'Book Title': 'Freedom',
#   'Book Subtitle': None,
#   'Book Author': 'Sebastian Junger',
#   'Book Narrator': 'Sebastian Junger',
#   'Audio Runtime': '3 hrs and 6 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Biographies & Memoirs',
#   'Rating': '4.7',
#   'Total No. of Ratings': 119,
#   'Price': '$18.89 '},
#  {'Book_ID': 50,
#   'Book Title': 'Children of Ash and Elm',
#   'Book Subtitle': 'A History of the Vikings',
#   'Book Author': 'Neil Price',
#   'Book Narrator': 'Samuel Roukin',
#   'Audio Runtime': '17 hrs and 25 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'History',
#   'Rating': '4.7',
#   'Total No. of Ratings': 313,
#   'Price': '$34.99 '},
#  {'Book_ID': 51,
#   'Book Title': 'Bloodline',
#   'Book Subtitle': 'Cradle, Book 9',
#   'Book Author': 'Will Wight',
#   'Book Narrator': 'Travis Baldree',
#   'Audio Runtime': '11 hrs and 12 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Science Fiction & Fantasy',
#   'Rating': '4.9',
#   'Total No. of Ratings': 4009,
#   'Price': '$24.95 '},
#  {'Book_ID': 52,
#   'Book Title': 'The Hope We Hold',
#   'Book Subtitle': 'Finding Peace in the Promises of God',
#   'Book Author': 'Jeremy Vuolo',
#   'Book Narrator': 'Jeremy Vuolo',
#   'Audio Runtime': '6 hrs and 8 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Biographies & Memoirs',
#   'Rating': '4.8',
#   'Total No. of Ratings': 418,
#   'Price': '$29.65 '},
#  {'Book_ID': 53,
#   'Book Title': 'Freed',
#   'Book Subtitle': 'Fifty Shades Freed as Told by Christian',
#   'Book Author': 'E. L. James',
#   'Book Narrator': 'Zachary Webber',
#   'Audio Runtime': '27 hrs and 15 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Literature & Fiction',
#   'Rating': None,
#   'Total No. of Ratings': None,
#   'Price': '$38.50 '},
#  {'Book_ID': 54,
#   'Book Title': 'Dark Imperium',
#   'Book Subtitle': 'Dark Imperium: Warhammer 40,000, Book 1',
#   'Book Author': 'Guy Haley',
#   'Book Narrator': 'John Banks',
#   'Audio Runtime': '11 hrs and 53 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Science Fiction & Fantasy',
#   'Rating': '5',
#   'Total No. of Ratings': 2,
#   'Price': '$32.71 '},
#  {'Book_ID': 55,
#   'Book Title': 'The Body Keeps the Score',
#   'Book Subtitle': 'Brain, Mind, and Body in the Healing of Trauma',
#   'Book Author': 'Bessel A. van der Kolk',
#   'Book Narrator': 'Sean Pratt',
#   'Audio Runtime': '16 hrs and 15 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Health & Wellness',
#   'Rating': '4.9',
#   'Total No. of Ratings': 538,
#   'Price': '$35.00 '},
#  {'Book_ID': 56,
#   'Book Title': 'Born a Crime',
#   'Book Subtitle': 'Stories from a South African Childhood',
#   'Book Author': 'Trevor Noah',
#   'Book Narrator': 'Trevor Noah',
#   'Audio Runtime': '8 hrs and 44 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Arts & Entertainment',
#   'Rating': '4.9',
#   'Total No. of Ratings': 182445,
#   'Price': '$24.95 '},
#  {'Book_ID': 57,
#   'Book Title': 'Great Circle',
#   'Book Subtitle': 'A Novel',
#   'Book Author': 'Maggie Shipstead',
#   'Book Narrator': 'Cassandra Campbell',
#   'Audio Runtime': '25 hrs and 16 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Literature & Fiction',
#   'Rating': '4.6',
#   'Total No. of Ratings': 78,
#   'Price': '$42.00 '},
#  {'Book_ID': 58,
#   'Book Title': 'Untamed',
#   'Book Subtitle': None,
#   'Book Author': 'Glennon Doyle',
#   'Book Narrator': 'Glennon Doyle',
#   'Audio Runtime': '8 hrs and 22 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Biographies & Memoirs',
#   'Rating': '4.7',
#   'Total No. of Ratings': 25827,
#   'Price': '$31.50 '},
#  {'Book_ID': 59,
#   'Book Title': 'The Invisible Life of Addie LaRue',
#   'Book Subtitle': None,
#   'Book Author': 'V. E. Schwab',
#   'Book Narrator': 'Julia Whelan',
#   'Audio Runtime': '17 hrs and 10 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Science Fiction & Fantasy',
#   'Rating': '4.6',
#   'Total No. of Ratings': 13536,
#   'Price': '$46.89 '},
#  {'Book_ID': 60,
#   'Book Title': 'The Vanishing Half',
#   'Book Subtitle': 'A Novel',
#   'Book Author': 'Brit Bennett',
#   'Book Narrator': 'Shayna Small',
#   'Audio Runtime': '11 hrs and 34 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Literature & Fiction',
#   'Rating': '4.5',
#   'Total No. of Ratings': 17012,
#   'Price': '$31.50 '},
#  {'Book_ID': 61,
#   'Book Title': 'Brat',
#   'Book Subtitle': "An '80s Story",
#   'Book Author': 'Andrew McCarthy',
#   'Book Narrator': 'Andrew McCarthy',
#   'Audio Runtime': '4 hrs and 55 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Biographies & Memoirs',
#   'Rating': '4.4',
#   'Total No. of Ratings': 392,
#   'Price': '$29.65 '},
#  {'Book_ID': 62,
#   'Book Title': 'Sooley',
#   'Book Subtitle': 'A Novel',
#   'Book Author': 'John Grisham',
#   'Book Narrator': 'Dion Graham',
#   'Audio Runtime': '10 hrs and 27 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Literature & Fiction',
#   'Rating': '4.7',
#   'Total No. of Ratings': 2466,
#   'Price': '$31.50 '},
#  {'Book_ID': 63,
#   'Book Title': 'Cleaning Up Your Mental Mess',
#   'Book Subtitle': '5 Simple, Scientifically Proven Steps to Reduce Anxiety, Stress, and Toxic Thinking',
#   'Book Author': 'Dr. Caroline Leaf',
#   'Book Narrator': 'Caroline Leaf',
#   'Audio Runtime': '8 hrs and 4 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Health & Wellness',
#   'Rating': '4.4',
#   'Total No. of Ratings': 164,
#   'Price': '$24.49 '},
#  {'Book_ID': 64,
#   'Book Title': 'The Mind Illuminated',
#   'Book Subtitle': 'A Complete Meditation Guide Integrating Buddhist Wisdom and Brain Science',
#   'Book Author': 'Culadasa John Yates PhD',
#   'Book Narrator': 'Sean Runnette',
#   'Audio Runtime': '16 hrs and 5 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Health & Wellness',
#   'Rating': '4.6',
#   'Total No. of Ratings': 367,
#   'Price': '$31.49 '},
#  {'Book_ID': 65,
#   'Book Title': "Carl's Doomsday Scenario",
#   'Book Subtitle': 'Dungeon Crawler Carl, Book 2',
#   'Book Author': 'Matt Dinniman',
#   'Book Narrator': 'Jeff Hays',
#   'Audio Runtime': '11 hrs and 28 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Literature & Fiction',
#   'Rating': '4.9',
#   'Total No. of Ratings': 737,
#   'Price': '$24.95 '},
#  {'Book_ID': 66,
#   'Book Title': 'Zero Fail',
#   'Book Subtitle': 'The Rise and Fall of the Secret Service',
#   'Book Author': 'Carol Leonnig',
#   'Book Narrator': 'Maggi-Meg Reed',
#   'Audio Runtime': '20 hrs and 26 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Politics & Social Sciences',
#   'Rating': '4.6',
#   'Total No. of Ratings': 225,
#   'Price': '$38.50 '},
#  {'Book_ID': 67,
#   'Book Title': 'Boundary Boss',
#   'Book Subtitle': 'The Essential Guide to Talk True, Be Seen, and (Finally) Live Free',
#   'Book Author': 'Terri Cole MSW LCSW',
#   'Book Narrator': 'Terri Cole MSW LCSW',
#   'Audio Runtime': '7 hrs and 54 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Relationships, Parenting & Personal Development',
#   'Rating': '5',
#   'Total No. of Ratings': 62,
#   'Price': '$14.69 '},
#  {'Book_ID': 68,
#   'Book Title': 'The Fifth Realm',
#   'Book Subtitle': 'A LitRPG Fantasy Series (The Ten Realms, Book 5)',
#   'Book Author': 'Michael Chatfield',
#   'Book Narrator': 'Todd Menesses',
#   'Audio Runtime': '26 hrs and 28 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Teen',
#   'Rating': '4.7',
#   'Total No. of Ratings': 1575,
#   'Price': '$29.95 '},
#  {'Book_ID': 69,
#   'Book Title': "The Dalai Lama's Cat + The Dalai Lama's Cat: Guided Meditations",
#   'Book Subtitle': None,
#   'Book Author': 'David Michie',
#   'Book Narrator': 'David Michie',
#   'Audio Runtime': '7 hrs and 14 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Literature & Fiction',
#   'Rating': '4.7',
#   'Total No. of Ratings': 333,
#   'Price': '$29.84 '},
#  {'Book_ID': 70,
#   'Book Title': 'The Midnight Library',
#   'Book Subtitle': 'A Novel',
#   'Book Author': 'Matt Haig',
#   'Book Narrator': 'Carey Mulligan',
#   'Audio Runtime': '8 hrs and 50 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Science Fiction & Fantasy',
#   'Rating': '4.6',
#   'Total No. of Ratings': 21253,
#   'Price': '$28.00 '},
#  {'Book_ID': 71,
#   'Book Title': 'The Never Army',
#   'Book Subtitle': 'Chronicles of Jonathan Tibbs, Book 3',
#   'Book Author': 'T. Ellery Hodges',
#   'Book Narrator': 'Steven Barnett',
#   'Audio Runtime': '31 hrs and 5 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Teen',
#   'Rating': '4.9',
#   'Total No. of Ratings': 138,
#   'Price': '$29.95 '},
#  {'Book_ID': 72,
#   'Book Title': 'Siege and Storm',
#   'Book Subtitle': None,
#   'Book Author': 'Leigh Bardugo',
#   'Book Narrator': 'Lauren Fortgang',
#   'Audio Runtime': '11 hrs and 49 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': None,
#   'Rating': '4.4',
#   'Total No. of Ratings': 6386,
#   'Price': '$24.95 '},
#  {'Book_ID': 73,
#   'Book Title': 'Extreme Ownership',
#   'Book Subtitle': 'How U.S. Navy SEALs Lead and Win',
#   'Book Author': 'Jocko Willink',
#   'Book Narrator': 'Jocko Willink',
#   'Audio Runtime': '9 hrs and 33 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Business & Careers',
#   'Rating': '4.8',
#   'Total No. of Ratings': 61779,
#   'Price': '$27.99 '},
#  {'Book_ID': 74,
#   'Book Title': 'Dune',
#   'Book Subtitle': None,
#   'Book Author': 'Frank Herbert',
#   'Book Narrator': 'Scott Brick',
#   'Audio Runtime': '21 hrs and 2 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Science Fiction & Fantasy',
#   'Rating': '4.6',
#   'Total No. of Ratings': 73222,
#   'Price': '$47.93 '},
#  {'Book_ID': 75,
#   'Book Title': 'Factfulness',
#   'Book Subtitle': "Ten Reasons We're Wrong About the World - and Why Things Are Better Than You Think",
#   'Book Author': 'Hans Rosling',
#   'Book Narrator': 'Richard Harries',
#   'Audio Runtime': '8 hrs and 51 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Health & Wellness',
#   'Rating': '4.6',
#   'Total No. of Ratings': 5490,
#   'Price': '$24.49 '},
#  {'Book_ID': 76,
#   'Book Title': 'The Girl Who Was Taken',
#   'Book Subtitle': None,
#   'Book Author': 'Charlie Donlea',
#   'Book Narrator': 'Nina Alvamar',
#   'Audio Runtime': '10 hrs and 49 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Mystery, Thriller & Suspense',
#   'Rating': '4.3',
#   'Total No. of Ratings': 10154,
#   'Price': '$27.99 '},
#  {'Book_ID': 77,
#   'Book Title': 'Building a StoryBrand',
#   'Book Subtitle': 'Clarify Your Message So Customers Will Listen',
#   'Book Author': 'Donald Miller',
#   'Book Narrator': 'Donald Miller',
#   'Audio Runtime': '4 hrs and 56 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Business & Careers',
#   'Rating': '4.8',
#   'Total No. of Ratings': 9528,
#   'Price': '$22.81 '},
#  {'Book_ID': 78,
#   'Book Title': 'The Charisma Myth',
#   'Book Subtitle': 'How Anyone Can Master the Art and Science of Personal Magnetism',
#   'Book Author': 'Olivia Fox Cabane',
#   'Book Narrator': 'Lisa Cordileione',
#   'Audio Runtime': '8 hrs and 20 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Business & Careers',
#   'Rating': '4.3',
#   'Total No. of Ratings': 5313,
#   'Price': '$24.49 '},
#  {'Book_ID': 79,
#   'Book Title': 'Redeeming Love',
#   'Book Subtitle': None,
#   'Book Author': 'Francine Rivers',
#   'Book Narrator': 'Kate Forbes',
#   'Audio Runtime': '17 hrs and 17 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Literature & Fiction',
#   'Rating': '4.8',
#   'Total No. of Ratings': 8238,
#   'Price': '$39.87 '},
#  {'Book_ID': 80,
#   'Book Title': 'Breaking the News',
#   'Book Subtitle': "Exposing the Establishment Media's Hidden Deals and Secret Corruption",
#   'Book Author': 'Alex Marlow',
#   'Book Narrator': 'Alex Marlow',
#   'Audio Runtime': '10 hrs and 34 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Politics & Social Sciences',
#   'Rating': '4.9',
#   'Total No. of Ratings': 130,
#   'Price': '$22.67 '},
#  {'Book_ID': 81,
#   'Book Title': 'Hillbilly Elegy',
#   'Book Subtitle': 'A Memoir of a Family and Culture in Crisis',
#   'Book Author': 'J. D. Vance',
#   'Book Narrator': 'J. D. Vance',
#   'Audio Runtime': '6 hrs and 49 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Politics & Social Sciences',
#   'Rating': '4.5',
#   'Total No. of Ratings': 50244,
#   'Price': '$25.09 '},
#  {'Book_ID': 82,
#   'Book Title': 'The Alchemist',
#   'Book Subtitle': 'A Fable About Following Your Dream',
#   'Book Author': 'Paulo Coelho',
#   'Book Narrator': 'Jeremy Irons',
#   'Audio Runtime': '4 hrs',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Literature & Fiction',
#   'Rating': '4.7',
#   'Total No. of Ratings': 61074,
#   'Price': '$23.95 '},
#  {'Book_ID': 83,
#   'Book Title': 'The Untethered Soul',
#   'Book Subtitle': 'The Journey Beyond Yourself',
#   'Book Author': 'Michael A. Singer',
#   'Book Narrator': 'Peter Berkrot',
#   'Audio Runtime': '6 hrs and 11 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Health & Wellness',
#   'Rating': '4.7',
#   'Total No. of Ratings': 20556,
#   'Price': '$24.49 '},
#  {'Book_ID': 84,
#   'Book Title': 'Thinking, Fast and Slow',
#   'Book Subtitle': None,
#   'Book Author': 'Daniel Kahneman',
#   'Book Narrator': 'Patrick Egan',
#   'Audio Runtime': '20 hrs and 2 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Business & Careers',
#   'Rating': '4.4',
#   'Total No. of Ratings': 16384,
#   'Price': '$35.00 '},
#  {'Book_ID': 85,
#   'Book Title': 'The Seven Husbands of Evelyn Hugo',
#   'Book Subtitle': 'A Novel',
#   'Book Author': 'Taylor Jenkins Reid',
#   'Book Narrator': 'Alma Cuervo',
#   'Audio Runtime': '12 hrs and 10 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'LGBTQ+',
#   'Rating': '4.6',
#   'Total No. of Ratings': 14286,
#   'Price': '$22.67 '},
#  {'Book_ID': 86,
#   'Book Title': 'The Comfort Crisis',
#   'Book Subtitle': 'Embrace Discomfort to Reclaim Your Wild, Happy, Healthy Self',
#   'Book Author': 'Michael Easter',
#   'Book Narrator': 'Michael Easter',
#   'Audio Runtime': '8 hrs and 52 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Health & Wellness',
#   'Rating': '4.9',
#   'Total No. of Ratings': 223,
#   'Price': '$28.00 '},
#  {'Book_ID': 87,
#   'Book Title': 'He Who Fights with Monsters 3',
#   'Book Subtitle': 'A LitRPG Adventure (He Who Fights with Monsters, Book 3)',
#   'Book Author': 'Shirtaloon',
#   'Book Narrator': 'Heath Miller',
#   'Audio Runtime': '25 hrs and 48 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Science Fiction & Fantasy',
#   'Rating': None,
#   'Total No. of Ratings': None,
#   'Price': '$59.99 '},
#  {'Book_ID': 88,
#   'Book Title': 'Alpha Male Bible',
#   'Book Subtitle': 'Charisma, Psychology of Attraction, Charm. Art of Confidence, Self-Hypnosis, Meditation. Art of Body Language, Eye Contact, Small Talk. Habits & Self-Discipline of a Real Alpha Man.',
#   'Book Author': 'Sean Wayne',
#   'Book Narrator': 'Perdens Studio',
#   'Audio Runtime': '12 hrs and 1 min',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Health & Wellness',
#   'Rating': '4.1',
#   'Total No. of Ratings': 742,
#   'Price': '$24.95 '},
#  {'Book_ID': 89,
#   'Book Title': 'Behold a Pale Horse',
#   'Book Subtitle': None,
#   'Book Author': 'Milton William Cooper',
#   'Book Narrator': 'Milton William Cooper',
#   'Audio Runtime': '2 hrs and 54 mins',
#   'Audiobook_Type': 'Abridged Audiobook',
#   'Categories': 'Religion & Spirituality',
#   'Rating': '4.7',
#   'Total No. of Ratings': 1958,
#   'Price': '$6.97 '},
#  {'Book_ID': 90,
#   'Book Title': 'Raising Good Humans',
#   'Book Subtitle': 'A Mindful Guide to Breaking the Cycle of Reactive Parenting and Raising Kind, Confident Kids',
#   'Book Author': 'Hunter Clarke-Fields MSAE',
#   'Book Narrator': 'Jennifer Gilmour',
#   'Audio Runtime': '5 hrs and 37 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Relationships, Parenting & Personal Development',
#   'Rating': '4.7',
#   'Total No. of Ratings': 100,
#   'Price': '$13.27 '},
#  {'Book_ID': 91,
#   'Book Title': "Beginner's Mind",
#   'Book Subtitle': None,
#   'Book Author': 'Yo-Yo Ma',
#   'Book Narrator': 'Yo-Yo Ma',
#   'Audio Runtime': '1 hr and 32 mins',
#   'Audiobook_Type': None,
#   'Categories': None,
#   'Rating': '5 out of 5 stars',
#   'Total No. of Ratings': 55,
#   'Price': '$0.00 '},
#  {'Book_ID': 92,
#   'Book Title': "The Handmaid's Tale: Special Edition",
#   'Book Subtitle': None,
#   'Book Author': 'Margaret Atwood',
#   'Book Narrator': 'Claire Danes',
#   'Audio Runtime': '12 hrs and 6 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Literature & Fiction',
#   'Rating': '4.5',
#   'Total No. of Ratings': 33627,
#   'Price': '$29.95 '},
#  {'Book_ID': 93,
#   'Book Title': 'People We Meet on Vacation',
#   'Book Subtitle': None,
#   'Book Author': 'Emily Henry',
#   'Book Narrator': 'Julia Whelan',
#   'Audio Runtime': '10 hrs and 46 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Literature & Fiction',
#   'Rating': '4.5',
#   'Total No. of Ratings': 761,
#   'Price': '$28.00 '},
#  {'Book_ID': 94,
#   'Book Title': 'The Rose Code',
#   'Book Subtitle': 'A Novel',
#   'Book Author': 'Kate Quinn',
#   'Book Narrator': 'Saskia Maarleveld',
#   'Audio Runtime': '15 hrs and 40 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Literature & Fiction',
#   'Rating': '4.8',
#   'Total No. of Ratings': 5189,
#   'Price': '$34.22 '},
#  {'Book_ID': 95,
#   'Book Title': "Caste (Oprah's Book Club)",
#   'Book Subtitle': 'The Origins of Our Discontents',
#   'Book Author': 'Isabel Wilkerson',
#   'Book Narrator': 'Robin Miles',
#   'Audio Runtime': '14 hrs and 26 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Politics & Social Sciences',
#   'Rating': '4.8',
#   'Total No. of Ratings': 12665,
#   'Price': '$31.50 '},
#  {'Book_ID': 96,
#   'Book Title': 'The Richest Man in Babylon',
#   'Book Subtitle': None,
#   'Book Author': 'George S. Clason',
#   'Book Narrator': 'Grover Gardner',
#   'Audio Runtime': '4 hrs and 4 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Business & Careers',
#   'Rating': '4.7',
#   'Total No. of Ratings': 19851,
#   'Price': '$14.95 '},
#  {'Book_ID': 97,
#   'Book Title': 'The Torch That Ignites the Stars',
#   'Book Subtitle': 'Arcane Ascension, Book 3',
#   'Book Author': 'Andrew Rowe',
#   'Book Narrator': 'Nick Podehl',
#   'Audio Runtime': '17 hrs and 21 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Science Fiction & Fantasy',
#   'Rating': '4.7',
#   'Total No. of Ratings': 2238,
#   'Price': '$44.99 '},
#  {'Book_ID': 98,
#   'Book Title': 'Empire of the Summer Moon',
#   'Book Subtitle': 'Quanah Parker and the Rise and Fall of the Comanches, the Most Powerful Indian Tribe in American History',
#   'Book Author': 'S. C. Gwynne',
#   'Book Narrator': 'David Drummond',
#   'Audio Runtime': '15 hrs and 9 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'History',
#   'Rating': '4.7',
#   'Total No. of Ratings': 8627,
#   'Price': '$22.67 '},
#  {'Book_ID': 99,
#   'Book Title': 'Is Everyone Hanging Out Without Me? (And Other Concerns)',
#   'Book Subtitle': None,
#   'Book Author': 'Mindy Kaling',
#   'Book Narrator': 'Mindy Kaling',
#   'Audio Runtime': '4 hrs and 37 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Arts & Entertainment',
#   'Rating': '4.3',
#   'Total No. of Ratings': 15851,
#   'Price': '$21.00 '},
#  {'Book_ID': 100,
#   'Book Title': 'Grit',
#   'Book Subtitle': 'The Power of Passion and Perseverance',
#   'Book Author': 'Angela Duckworth',
#   'Book Narrator': 'Angela Duckworth',
#   'Audio Runtime': '9 hrs and 22 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Business & Careers',
#   'Rating': '4.7',
#   'Total No. of Ratings': 21980,
#   'Price': '$20.99 '},
#  {'Book_ID': 101,
#   'Book Title': 'Good to Great',
#   'Book Subtitle': "Why Some Companies Make the Leap...And Others Don't",
#   'Book Author': 'Jim Collins',
#   'Book Narrator': 'Jim Collins',
#   'Audio Runtime': '10 hrs and 1 min',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Business & Careers',
#   'Rating': '4.5',
#   'Total No. of Ratings': 14533,
#   'Price': '$36.50 '},
#  {'Book_ID': 102,
#   'Book Title': '21st Birthday',
#   'Book Subtitle': None,
#   'Book Author': 'James Patterson',
#   'Book Narrator': 'January LaVoy',
#   'Audio Runtime': '8 hrs and 50 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Mystery, Thriller & Suspense',
#   'Rating': '4.6',
#   'Total No. of Ratings': 1011,
#   'Price': '$30.79 '},
#  {'Book_ID': 103,
#   'Book Title': 'Braiding Sweetgrass',
#   'Book Subtitle': 'Indigenous Wisdom, Scientific Knowledge and the Teachings of Plants',
#   'Book Author': 'Robin Wall Kimmerer',
#   'Book Narrator': 'Robin Wall Kimmerer',
#   'Audio Runtime': '16 hrs and 44 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'History',
#   'Rating': '4.8',
#   'Total No. of Ratings': 4479,
#   'Price': '$34.99 '},
#  {'Book_ID': 104,
#   'Book Title': 'Ruin and Rising',
#   'Book Subtitle': None,
#   'Book Author': 'Leigh Bardugo',
#   'Book Narrator': 'Lauren Fortgang',
#   'Audio Runtime': '10 hrs and 57 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Teen',
#   'Rating': '4.6',
#   'Total No. of Ratings': 5741,
#   'Price': '$24.95 '},
#  {'Book_ID': 105,
#   'Book Title': 'Wiseguy',
#   'Book Subtitle': None,
#   'Book Author': 'Nicholas Pileggi',
#   'Book Narrator': 'Ari Fliakos',
#   'Audio Runtime': '8 hrs and 15 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Biographies & Memoirs',
#   'Rating': '4.8',
#   'Total No. of Ratings': 1155,
#   'Price': '$22.67 '},
#  {'Book_ID': 106,
#   'Book Title': "Can't Hurt Me",
#   'Book Subtitle': 'Master Your Mind and Defy the Odds',
#   'Book Author': 'David Goggins',
#   'Book Narrator': 'David Goggins',
#   'Audio Runtime': '13 hrs and 37 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Relationships, Parenting & Personal Development',
#   'Rating': '4.9',
#   'Total No. of Ratings': 136442,
#   'Price': '$24.95 '},
#  {'Book_ID': 107,
#   'Book Title': 'The Push',
#   'Book Subtitle': 'A Novel',
#   'Book Author': 'Ashley Audrain',
#   'Book Narrator': 'Marin Ireland',
#   'Audio Runtime': '8 hrs and 38 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Literature & Fiction',
#   'Rating': '4.5',
#   'Total No. of Ratings': 4041,
#   'Price': '$28.00 '},
#  {'Book_ID': 108,
#   'Book Title': 'Dungeon Walkers 1',
#   'Book Subtitle': None,
#   'Book Author': 'Daniel Schinhofen',
#   'Book Narrator': 'Travis Baldree',
#   'Audio Runtime': '11 hrs and 22 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Science Fiction & Fantasy',
#   'Rating': '4.5',
#   'Total No. of Ratings': 33,
#   'Price': '$24.95 '},
#  {'Book_ID': 109,
#   'Book Title': 'The Anthropocene Reviewed',
#   'Book Subtitle': 'Essays on a Human-Centered Planet',
#   'Book Author': 'John Green',
#   'Book Narrator': 'John Green',
#   'Audio Runtime': '10 hrs and 3 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Literature & Fiction',
#   'Rating': '4.9',
#   'Total No. of Ratings': 362,
#   'Price': '$28.00 '},
#  {'Book_ID': 110,
#   'Book Title': 'Unfu*k Yourself',
#   'Book Subtitle': 'Get Out of Your Head and into Your Life',
#   'Book Author': 'Gary John Bishop',
#   'Book Narrator': 'Gary John Bishop',
#   'Audio Runtime': '3 hrs and 24 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Relationships, Parenting & Personal Development',
#   'Rating': '4.6',
#   'Total No. of Ratings': 73022,
#   'Price': '$20.52 '},
#  {'Book_ID': 111,
#   'Book Title': 'The Fellowship of the Ring',
#   'Book Subtitle': 'Book One in The Lord of the Rings Trilogy',
#   'Book Author': 'J. R. R. Tolkien',
#   'Book Narrator': 'Rob Inglis',
#   'Audio Runtime': '19 hrs and 7 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Literature & Fiction',
#   'Rating': '4.8',
#   'Total No. of Ratings': 51180,
#   'Price': '$38.49 '},
#  {'Book_ID': 112,
#   'Book Title': 'State of Emergency',
#   'Book Subtitle': 'How We Win in the Country We Built',
#   'Book Author': 'Tamika D. Mallory',
#   'Book Narrator': 'Tamika D. Mallory',
#   'Audio Runtime': '6 hrs and 38 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Biographies & Memoirs',
#   'Rating': '4.9',
#   'Total No. of Ratings': 128,
#   'Price': '$17.00 '},
#  {'Book_ID': 113,
#   'Book Title': 'The Intelligent Investor Rev Ed.',
#   'Book Subtitle': None,
#   'Book Author': 'Benjamin Graham',
#   'Book Narrator': 'Luke Daniels',
#   'Audio Runtime': '17 hrs and 48 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Money & Finance',
#   'Rating': '4.6',
#   'Total No. of Ratings': 5605,
#   'Price': '$42.20 '},
#  {'Book_ID': 114,
#   'Book Title': 'Boundaries, Updated and Expanded Edition',
#   'Book Subtitle': 'When to Say Yes, How to Say No to Take Control of Your Life',
#   'Book Author': 'John Townsend',
#   'Book Narrator': 'Henry O. Arnold',
#   'Audio Runtime': '11 hrs and 18 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Relationships, Parenting & Personal Development',
#   'Rating': '4.6',
#   'Total No. of Ratings': 4473,
#   'Price': '$30.79 '},
#  {'Book_ID': 115,
#   'Book Title': 'I Want to Be Where the Normal People Are',
#   'Book Subtitle': None,
#   'Book Author': 'Rachel Bloom',
#   'Book Narrator': 'Rachel Bloom',
#   'Audio Runtime': '4 hrs and 51 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Biographies & Memoirs',
#   'Rating': '4.8',
#   'Total No. of Ratings': 641,
#   'Price': '$29.65 '},
#  {'Book_ID': 116,
#   'Book Title': 'Herald of Shalia 3',
#   'Book Subtitle': None,
#   'Book Author': 'Tamryn Tamer',
#   'Book Narrator': 'Amber Lee Connors',
#   'Audio Runtime': '12 hrs and 26 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Science Fiction & Fantasy',
#   'Rating': '4.9',
#   'Total No. of Ratings': 356,
#   'Price': '$24.95 '},
#  {'Book_ID': 117,
#   'Book Title': 'Ten Lessons for a Post-Pandemic World',
#   'Book Subtitle': None,
#   'Book Author': 'Fareed Zakaria',
#   'Book Narrator': 'Fareed Zakaria',
#   'Audio Runtime': '7 hrs and 24 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Politics & Social Sciences',
#   'Rating': '4.7',
#   'Total No. of Ratings': 881,
#   'Price': '$22.67 '},
#  {'Book_ID': 118,
#   'Book Title': 'The Total Money Makeover',
#   'Book Subtitle': 'A Proven Plan for Financial Fitness',
#   'Book Author': 'Dave Ramsey',
#   'Book Narrator': 'Dave Ramsey',
#   'Audio Runtime': '3 hrs and 41 mins',
#   'Audiobook_Type': 'Abridged Audiobook',
#   'Categories': 'Business & Careers',
#   'Rating': '4.7',
#   'Total No. of Ratings': 38683,
#   'Price': '$20.52 '},
#  {'Book_ID': 119,
#   'Book Title': 'The 4-Hour Workweek: Escape 9-5, Live Anywhere, and Join the New Rich (Expanded and Updated)',
#   'Book Subtitle': None,
#   'Book Author': 'Timothy Ferriss',
#   'Book Narrator': 'Ray Porter',
#   'Audio Runtime': '13 hrs and 1 min',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Business & Careers',
#   'Rating': '4.5',
#   'Total No. of Ratings': 18519,
#   'Price': '$23.07 '},
#  {'Book_ID': 120,
#   'Book Title': 'A Thousand Ships',
#   'Book Subtitle': 'A Novel',
#   'Book Author': 'Natalie Haynes',
#   'Book Narrator': 'Natalie Haynes',
#   'Audio Runtime': '8 hrs and 34 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Literature & Fiction',
#   'Rating': '4.7',
#   'Total No. of Ratings': 336,
#   'Price': '$27.37 '},
#  {'Book_ID': 121,
#   'Book Title': 'Humankind',
#   'Book Subtitle': 'A Hopeful History',
#   'Book Author': 'Rutger Bregman',
#   'Book Narrator': 'Rutger Bregman',
#   'Audio Runtime': '11 hrs and 37 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Health & Wellness',
#   'Rating': '4.8',
#   'Total No. of Ratings': 930,
#   'Price': '$29.65 '},
#  {'Book_ID': 122,
#   'Book Title': 'Your Brain at Work, Revised and Updated',
#   'Book Subtitle': 'Strategies for Overcoming Distraction, Regaining Focus, and Working Smarter All Day Long',
#   'Book Author': 'David Rock',
#   'Book Narrator': 'Roger Wayne',
#   'Audio Runtime': '9 hrs and 24 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Business & Careers',
#   'Rating': '4.9',
#   'Total No. of Ratings': 50,
#   'Price': '$30.79 '},
#  {'Book_ID': 123,
#   'Book Title': 'Killing the Mob',
#   'Book Subtitle': 'The Fight Against Organized Crime in America',
#   'Book Author': "Bill O'Reilly",
#   'Book Narrator': 'Robert Petkoff',
#   'Audio Runtime': '10 hrs and 5 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Biographies & Memoirs',
#   'Rating': '4.8',
#   'Total No. of Ratings': 982,
#   'Price': '$27.99 '},
#  {'Book_ID': 124,
#   'Book Title': '48 Laws of Power',
#   'Book Subtitle': None,
#   'Book Author': 'Robert Greene',
#   'Book Narrator': 'Richard Poe',
#   'Audio Runtime': '23 hrs and 6 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Politics & Social Sciences',
#   'Rating': '4.6',
#   'Total No. of Ratings': 16175,
#   'Price': '$24.49 '},
#  {'Book_ID': 125,
#   'Book Title': 'The Song of Achilles',
#   'Book Subtitle': 'A Novel',
#   'Book Author': 'Madeline Miller',
#   'Book Narrator': 'Frazer Douglas',
#   'Audio Runtime': '11 hrs and 15 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Literature & Fiction',
#   'Rating': '4.6',
#   'Total No. of Ratings': 21428,
#   'Price': '$30.79 '},
#  {'Book_ID': 126,
#   'Book Title': 'The Truth About Covid-19',
#   'Book Subtitle': 'Exposing the Great Reset, Lockdowns, Vaccine Passports, and the New Normal',
#   'Book Author': 'Dr. Joseph Mercola',
#   'Book Narrator': 'Nolan Chase',
#   'Audio Runtime': '7 hrs and 55 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Health & Wellness',
#   'Rating': '4.9',
#   'Total No. of Ratings': 201,
#   'Price': '$19.95 '},
#  {'Book_ID': 127,
#   'Book Title': 'The Underground Railroad (Television Tie-in)',
#   'Book Subtitle': 'A Novel',
#   'Book Author': 'Colson Whitehead',
#   'Book Narrator': 'Bahni Turpin',
#   'Audio Runtime': '10 hrs and 43 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Literature & Fiction',
#   'Rating': '4.4',
#   'Total No. of Ratings': 14937,
#   'Price': '$28.00 '},
#  {'Book_ID': 128,
#   'Book Title': 'Faucian Bargain',
#   'Book Subtitle': 'The Most Powerful and Dangerous Bureaucrat in American History',
#   'Book Author': 'Steve Deace',
# ...
#   'Rating': '4.7',
#   'Total No. of Ratings': 12984,
#   'Price': '$39.95 '},
#  {'Book_ID': 959,
#   'Book Title': 'Checking In',
#   'Book Subtitle': 'How Getting Real About Depression Saved My Life - and Can Save Yours',
#   'Book Author': 'Michelle Williams',
#   'Book Narrator': 'Michelle Williams',
#   'Audio Runtime': '5 hrs and 20 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Biographies & Memoirs',
#   'Rating': '5',
#   'Total No. of Ratings': 31,
#   'Price': '$23.95 '},
#  {'Book_ID': 960,
#   'Book Title': 'Path of Daggers',
#   'Book Subtitle': 'Book Eight of The Wheel of Time',
#   'Book Author': 'Robert Jordan',
#   'Book Narrator': 'Michael Kramer',
#   'Audio Runtime': '23 hrs and 25 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Science Fiction & Fantasy',
#   'Rating': '4.6',
#   'Total No. of Ratings': 20170,
#   'Price': '$55.93 '},
#  {'Book_ID': 961,
#   'Book Title': "The Judge's List",
#   'Book Subtitle': 'A Novel',
#   'Book Author': 'John Grisham',
#   'Book Narrator': None,
#   'Audio Runtime': '18 hrs',
#   'Audiobook_Type': None,
#   'Categories': None,
#   'Rating': 'Not rated yet',
#   'Total No. of Ratings': None,
#   'Price': '$35.00 '},
#  {'Book_ID': 962,
#   'Book Title': 'Cosmic Queries',
#   'Book Subtitle': 'StarTalk’s Guide to Who We Are, How We Got Here, and Where We’re Going',
#   'Book Author': 'James Trefil',
#   'Book Narrator': 'Neil deGrasse Tyson',
#   'Audio Runtime': '6 hrs and 18 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Politics & Social Sciences',
#   'Rating': '4.7',
#   'Total No. of Ratings': 282,
#   'Price': '$20.97 '},
#  {'Book_ID': 963,
#   'Book Title': "Let's Talk About Hard Things",
#   'Book Subtitle': None,
#   'Book Author': 'Anna Sale',
#   'Book Narrator': 'Anna Sale',
#   'Audio Runtime': '8 hrs and 3 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Health & Wellness',
#   'Rating': '4.6',
#   'Total No. of Ratings': 35,
#   'Price': '$18.89 '},
#  {'Book_ID': 964,
#   'Book Title': 'Israel',
#   'Book Subtitle': 'A Simple Guide to the Most Misunderstood Country on Earth',
#   'Book Author': 'Noa Tishby',
#   'Book Narrator': 'Noa Tishby',
#   'Audio Runtime': '9 hrs and 39 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'History',
#   'Rating': '4.8',
#   'Total No. of Ratings': 116,
#   'Price': '$18.89 '},
#  {'Book_ID': 965,
#   'Book Title': 'I Thee Take',
#   'Book Subtitle': 'To Have and to Hold Duet, Book 2',
#   'Book Author': 'Natasha Knight',
#   'Book Narrator': 'Wen Ross',
#   'Audio Runtime': '7 hrs and 21 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Literature & Fiction',
#   'Rating': '4.8',
#   'Total No. of Ratings': 144,
#   'Price': '$19.95 '},
#  {'Book_ID': 966,
#   'Book Title': 'The Red Book',
#   'Book Subtitle': None,
#   'Book Author': 'James Patterson',
#   'Book Narrator': 'Edoardo Ballerini',
#   'Audio Runtime': '8 hrs and 35 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Mystery, Thriller & Suspense',
#   'Rating': '4.6',
#   'Total No. of Ratings': 1194,
#   'Price': '$30.79 '},
#  {'Book_ID': 967,
#   'Book Title': 'Off the Record',
#   'Book Subtitle': 'A With Me in Seattle Mafia Novel',
#   'Book Author': 'Kristen Proby',
#   'Book Narrator': 'Jason Clarke',
#   'Audio Runtime': '5 hrs',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Romance',
#   'Rating': '4.6',
#   'Total No. of Ratings': 63,
#   'Price': '$19.95 '},
#  {'Book_ID': 968,
#   'Book Title': "Don't Believe the Swipe",
#   'Book Subtitle': 'Finding Love Without Losing Yourself',
#   'Book Author': 'Mandy Hale',
#   'Book Narrator': 'Emily Ellet',
#   'Audio Runtime': '6 hrs and 17 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Relationships, Parenting & Personal Development',
#   'Rating': '4.8',
#   'Total No. of Ratings': 11,
#   'Price': '$17.49 '},
#  {'Book_ID': 969,
#   'Book Title': 'The Searcher',
#   'Book Subtitle': 'A Novel',
#   'Book Author': 'Tana French',
#   'Book Narrator': 'Roger Clark',
#   'Audio Runtime': '14 hrs and 32 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Literature & Fiction',
#   'Rating': '4.3',
#   'Total No. of Ratings': 6709,
#   'Price': '$31.50 '},
#  {'Book_ID': 970,
#   'Book Title': 'The Next Wife',
#   'Book Subtitle': None,
#   'Book Author': 'Kaira Rouda',
#   'Book Narrator': 'Megan Tusing',
#   'Audio Runtime': '9 hrs and 46 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Mystery, Thriller & Suspense',
#   'Rating': '3.8',
#   'Total No. of Ratings': 232,
#   'Price': '$30.09 '},
#  {'Book_ID': 971,
#   'Book Title': 'Billion Dollar Loser',
#   'Book Subtitle': 'The Epic Rise and Spectacular Fall of Adam Neumann and WeWork',
#   'Book Author': 'Reeves Wiedeman',
#   'Book Narrator': 'Will Collyer',
#   'Audio Runtime': '10 hrs and 51 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Biographies & Memoirs',
#   'Rating': '4.6',
#   'Total No. of Ratings': 1080,
#   'Price': '$29.65 '},
#  {'Book_ID': 972,
#   'Book Title': 'Undaunted Courage',
#   'Book Subtitle': None,
#   'Book Author': 'Stephen E. Ambrose',
#   'Book Narrator': 'Barrett Whitener',
#   'Audio Runtime': '21 hrs and 40 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Biographies & Memoirs',
#   'Rating': '4.5',
#   'Total No. of Ratings': 4443,
#   'Price': '$39.95 '},
#  {'Book_ID': 973,
#   'Book Title': 'Fly Away',
#   'Book Subtitle': None,
#   'Book Author': 'Kristin Hannah',
#   'Book Narrator': 'Susan Ericksen',
#   'Audio Runtime': '16 hrs and 4 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Literature & Fiction',
#   'Rating': '4.5',
#   'Total No. of Ratings': 3092,
#   'Price': '$31.18 '},
#  {'Book_ID': 974,
#   'Book Title': 'Up Close and Personal',
#   'Book Subtitle': 'Auckland Med, Book 3',
#   'Book Author': 'Jay Hogan',
#   'Book Narrator': 'Gary Furlong',
#   'Audio Runtime': '10 hrs and 29 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Romance',
#   'Rating': '5',
#   'Total No. of Ratings': 1,
#   'Price': '$24.95 '},
#  {'Book_ID': 975,
#   'Book Title': 'A Vampire in Waikiki',
#   'Book Subtitle': None,
#   'Book Author': 'A.J. Llewellyn',
#   'Book Narrator': 'Michael Dean',
#   'Audio Runtime': '5 hrs and 44 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Romance',
#   'Rating': '4.7',
#   'Total No. of Ratings': 3,
#   'Price': '$19.95 '},
#  {'Book_ID': 976,
#   'Book Title': 'Court Kept',
#   'Book Subtitle': 'Court High, Book 3',
#   'Book Author': "Eden O'Neill",
#   'Book Narrator': 'Kasi Hollowell',
#   'Audio Runtime': '5 hrs and 10 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Romance',
#   'Rating': '5',
#   'Total No. of Ratings': 1,
#   'Price': '$19.95 '},
#  {'Book_ID': 977,
#   'Book Title': 'The Sex Traveler',
#   'Book Subtitle': None,
#   'Book Author': 'Tamara Kool',
#   'Book Narrator': 'Pamela Peterson',
#   'Audio Runtime': '1 hr and 54 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Erotica',
#   'Rating': '5',
#   'Total No. of Ratings': 1,
#   'Price': '$6.95 '},
#  {'Book_ID': 978,
#   'Book Title': 'Ruthless Creatures',
#   'Book Subtitle': 'Queens & Monsters, Book 1',
#   'Book Author': 'J.T. Geissinger',
#   'Book Narrator': 'Troy Duran',
#   'Audio Runtime': '10 hrs and 25 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Mystery, Thriller & Suspense',
#   'Rating': '4.8',
#   'Total No. of Ratings': 38,
#   'Price': '$24.95 '},
#  {'Book_ID': 979,
#   'Book Title': 'Evermore Academy: Summer',
#   'Book Subtitle': None,
#   'Book Author': 'Audrey Grey',
#   'Book Narrator': 'Vanessa Moyen',
#   'Audio Runtime': '11 hrs and 25 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Romance',
#   'Rating': '4.5',
#   'Total No. of Ratings': 23,
#   'Price': '$24.95 '},
#  {'Book_ID': 980,
#   'Book Title': 'Nothing Personal',
#   'Book Subtitle': 'My Secret Life in the Dating App Inferno',
#   'Book Author': 'Nancy Jo Sales',
#   'Book Narrator': 'Therese Plummer',
#   'Audio Runtime': '12 hrs and 27 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Biographies & Memoirs',
#   'Rating': '4.5',
#   'Total No. of Ratings': 2,
#   'Price': '$29.65 '},
#  {'Book_ID': 981,
#   'Book Title': 'Metabolical',
#   'Book Subtitle': 'The Lure and the Lies of Processed Food, Nutrition, and Modern Medicine',
#   'Book Author': 'Robert H. Lustig',
#   'Book Narrator': 'Charles Constant',
#   'Audio Runtime': '12 hrs and 3 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Health & Wellness',
#   'Rating': '4.8',
#   'Total No. of Ratings': 82,
#   'Price': '$30.79 '},
#  {'Book_ID': 982,
#   'Book Title': 'The Pillars of the Earth',
#   'Book Subtitle': None,
#   'Book Author': 'Ken Follett',
#   'Book Narrator': 'John Lee',
#   'Audio Runtime': '40 hrs and 56 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Literature & Fiction',
#   'Rating': '4.6',
#   'Total No. of Ratings': 30636,
#   'Price': '$56.00 '},
#  {'Book_ID': 983,
#   'Book Title': 'The Defining Decade',
#   'Book Subtitle': 'Why Your Twenties Matter - and How to Make the Most of Them Now',
#   'Book Author': 'Meg Jay',
#   'Book Narrator': 'Meg Jay',
#   'Audio Runtime': '7 hrs and 11 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Health & Wellness',
#   'Rating': '4.9',
#   'Total No. of Ratings': 93,
#   'Price': '$28.50 '},
#  {'Book_ID': 984,
#   'Book Title': 'Persist',
#   'Book Subtitle': None,
#   'Book Author': 'Elizabeth Warren',
#   'Book Narrator': 'Elizabeth Warren',
#   'Audio Runtime': '10 hrs and 35 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Biographies & Memoirs',
#   'Rating': '4.8',
#   'Total No. of Ratings': 127,
#   'Price': '$27.99 '},
#  {'Book_ID': 985,
#   'Book Title': 'Rocket Fuel',
#   'Book Subtitle': 'The One Essential Combination That Will Get You More of What You Want from Your Business',
#   'Book Author': 'Gino Wickman',
#   'Book Narrator': 'Mark C. Winters',
#   'Audio Runtime': '4 hrs and 26 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Business & Careers',
#   'Rating': '4.6',
#   'Total No. of Ratings': 1150,
#   'Price': '$14.95 '},
#  {'Book_ID': 986,
#   'Book Title': 'The Six Pillars of Self-Esteem',
#   'Book Subtitle': None,
#   'Book Author': 'Dr. Nathaniel Branden',
#   'Book Narrator': 'Dr. Nathaniel Branden',
#   'Audio Runtime': '3 hrs and 23 mins',
#   'Audiobook_Type': 'Abridged Audiobook',
#   'Categories': 'Health & Wellness',
#   'Rating': '4.6',
#   'Total No. of Ratings': 2133,
#   'Price': '$13.27 '},
#  {'Book_ID': 987,
#   'Book Title': 'White Evangelical Racism',
#   'Book Subtitle': 'The Politics of Morality in America',
#   'Book Author': 'Anthea Butler',
#   'Book Narrator': 'Allyson Johnson',
#   'Audio Runtime': '3 hrs and 44 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'History',
#   'Rating': '4.7',
#   'Total No. of Ratings': 70,
#   'Price': '$13.99 '},
#  {'Book_ID': 988,
#   'Book Title': 'Secret Manipulation Techniques',
#   'Book Subtitle': 'How Subliminal Psychology Can Persuade Anyone by Applying Dark NLP in Real Life. Understanding Tactics & Schemes to Influence People and Control Their Emotions (Mind Mastery, Book 2)',
#   'Book Author': 'Liam Robinson',
#   'Book Narrator': 'Diedra Eby',
#   'Audio Runtime': '3 hrs and 34 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Health & Wellness',
#   'Rating': '4',
#   'Total No. of Ratings': 114,
#   'Price': '$14.95 '},
#  {'Book_ID': 989,
#   'Book Title': 'The Drunken Botanist',
#   'Book Subtitle': "The Plants That Create the World's Great Drinks",
#   'Book Author': 'Amy Stewart',
#   'Book Narrator': 'Coleen Marlo',
#   'Audio Runtime': '10 hrs and 16 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'History',
#   'Rating': '4',
#   'Total No. of Ratings': 813,
#   'Price': '$20.27 '},
#  {'Book_ID': 990,
#   'Book Title': 'The Decision',
#   'Book Subtitle': "Overcoming Today's BS for Tomorrow's Success",
#   'Book Author': 'Kevin Hart',
#   'Book Narrator': 'Kevin Hart',
#   'Audio Runtime': '5 hrs and 54 mins',
#   'Audiobook_Type': 'Original Recording Audiobook',
#   'Categories': 'Relationships, Parenting & Personal Development',
#   'Rating': '4.8',
#   'Total No. of Ratings': 7972,
#   'Price': '$29.95 '},
#  {'Book_ID': 991,
#   'Book Title': 'An Absolutely Remarkable Thing',
#   'Book Subtitle': 'A Novel',
#   'Book Author': 'Hank Green',
#   'Book Narrator': 'Kristen Sieh',
#   'Audio Runtime': '9 hrs and 25 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Literature & Fiction',
#   'Rating': '4.7',
#   'Total No. of Ratings': 5844,
#   'Price': '$28.00 '},
#  {'Book_ID': 992,
#   'Book Title': 'Crushing It!',
#   'Book Subtitle': 'How Great Entrepreneurs Build Their Business and Influence-and How You Can, Too',
#   'Book Author': 'Gary Vaynerchuk',
#   'Book Narrator': 'Gary Vaynerchuk',
#   'Audio Runtime': '8 hrs and 2 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Business & Careers',
#   'Rating': '4.7',
#   'Total No. of Ratings': 12910,
#   'Price': '$27.37 '},
#  {'Book_ID': 993,
#   'Book Title': 'The Girl on the Train',
#   'Book Subtitle': 'A Novel',
#   'Book Author': 'Paula Hawkins',
#   'Book Narrator': 'Clare Corbett',
#   'Audio Runtime': '10 hrs and 58 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Literature & Fiction',
#   'Rating': '4.4',
#   'Total No. of Ratings': 137770,
#   'Price': '$28.00 '},
#  {'Book_ID': 994,
#   'Book Title': 'Tribe of Mentors',
#   'Book Subtitle': 'Short Life Advice from the Best in the World',
#   'Book Author': 'Tim Ferriss',
#   'Book Narrator': 'Kaleo Griffith',
#   'Audio Runtime': '18 hrs and 43 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Business & Careers',
#   'Rating': '4.7',
#   'Total No. of Ratings': 722,
#   'Price': '$39.95 '},
#  {'Book_ID': 995,
#   'Book Title': 'The Marriage Game',
#   'Book Subtitle': None,
#   'Book Author': 'Sara Desai',
#   'Book Narrator': 'Soneela Nankani',
#   'Audio Runtime': '11 hrs and 38 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Literature & Fiction',
#   'Rating': '4.4',
#   'Total No. of Ratings': 73,
#   'Price': '$28.00 '},
#  {'Book_ID': 996,
#   'Book Title': 'Recapture the Rapture',
#   'Book Subtitle': 'Rethinking God, Sex, and Death in a World That’s Lost Its Mind',
#   'Book Author': 'Jamie Wheal',
#   'Book Narrator': 'Jamie Wheal',
#   'Audio Runtime': '14 hrs and 29 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Health & Wellness',
#   'Rating': '4.8',
#   'Total No. of Ratings': 82,
#   'Price': '$34.22 '},
#  {'Book_ID': 997,
#   'Book Title': 'Son of the Storm',
#   'Book Subtitle': None,
#   'Book Author': 'Suyi Davies Okungbowa',
#   'Book Narrator': 'Korey Jackson',
#   'Audio Runtime': '17 hrs and 46 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Literature & Fiction',
#   'Rating': '4.7',
#   'Total No. of Ratings': 12,
#   'Price': '$29.65 '},
#  {'Book_ID': 998,
#   'Book Title': 'Critical Race Theory: An Introduction, Third Edition',
#   'Book Subtitle': 'Critical America, Book 20',
#   'Book Author': 'Richard Delgado',
#   'Book Narrator': 'Karen Chilton',
#   'Audio Runtime': '5 hrs and 39 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Politics & Social Sciences',
#   'Rating': '4.2',
#   'Total No. of Ratings': 130,
#   'Price': '$19.95 '},
#  {'Book_ID': 999,
#   'Book Title': 'Law of Attraction, Get Your Ex Back',
#   'Book Subtitle': 'No Contact Rule: Proven Techniques to Attract a Specific Person, Get Your Ex Back. Manifesting Love | Health | Success | Wealth | …Happiness',
#   'Book Author': 'Esther Greene',
#   'Book Narrator': 'Perden Studio',
#   'Audio Runtime': '6 hrs and 50 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Relationships, Parenting & Personal Development',
#   'Rating': '4.5',
#   'Total No. of Ratings': 153,
#   'Price': '$19.95 '},
#  {'Book_ID': 1000,
#   'Book Title': 'Rememberings',
#   'Book Subtitle': None,
#   'Book Author': "Sinéad O'Connor",
#   'Book Narrator': "Sinéad O'Connor",
#   'Audio Runtime': '7 hrs and 15 mins',
#   'Audiobook_Type': 'Unabridged Audiobook',
#   'Categories': 'Biographies & Memoirs',
#   'Rating': None,
#   'Total No. of Ratings': None,
#   'Price': '$19.60 '},
#  ...]

# %%
# ดูประเภทของ result
type(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-00b2e1ecdd47> in <module>
#       1 # ดูประเภทของ result
# ----> 2 type(result)
#
# NameError: name 'result' is not defined

# %% [markdown]
# ประเภทของตัวแปร คือ list (เป็น list ของ dictionary แต่ละบรรทัด)

# %% [markdown]
# Row เยอะแบบนี้ print ออกมาดูไม่ได้
#
# ใช้งานลำบากอีก ขอแนะนำว่า `Pandas` ช่วยคุณได้ ʕ•́ᴥ•̀ʔ
#
# ## Convert to Pandas
# เพื่อตารางที่สวยงามของเรา

# %%
import pandas as pd

# %%
audible_data = pd.DataFrame(result)

# %%
type(audible_data)
# Out:
# pandas.core.frame.DataFrame

# %%
audible_data
# Out:
#       Book_ID                                         Book Title  \
# 0           1                                Bamboozled by Jesus
# 1           2                                 Sixth Realm Part 1
# 2           3                    Go Tell the Bees That I Am Gone
# 3           4                             How the Word Is Passed
# 4           5                                The Devil May Dance
# ...       ...                                                ...
# 2264     2265                                         Kama Sutra
# 2265     2266  Meditación Práctica para Principiantes [Prac...
# 2266     2267                                          Forgotten
# 2267     2268                                        The Missing
# 2268     2269                                           Becoming
#
#                                           Book Subtitle        Book Author  \
# 0         How God Tricked Me into the Life of My Dreams        Yvonne Orji
# 1      A LitRPG Fantasy Series (The Ten Realms, Book 6)  Michael Chatfield
# 2                                     Outlander, Book 9     Diana Gabaldon
# 3     A Reckoning with the History of Slavery Across...        Clint Smith
# 4                                               A Novel        Jake Tapper
# ...                                                 ...                ...
# 2264  Become a Master of the Art of Love Making. Tan...         Eva Becker
# 2265  Una guía para principiantes para aliviar la an...        Taylor Knox
# 2266  The Untold Story of D-day's Black Heroes, at H...     Linda Hervieux
# 2267                                               None       Daisy Pearce
# 2268                                               None     Michelle Obama
#
#         Book Narrator       Audio Runtime        Audiobook_Type  \
# 0         Yvonne Orji   6 hrs and 31 mins  Unabridged Audiobook
# 1      Neil Hellegers  13 hrs and 33 mins  Unabridged Audiobook
# 2       Davina Porter  27 hrs and 30 mins  Unabridged Audiobook
# 3         Clint Smith   10 hrs and 7 mins  Unabridged Audiobook
# 4         Rob Shapiro  10 hrs and 12 mins  Unabridged Audiobook
# ...               ...                 ...                   ...
# 2264      ChasMandala   3 hrs and 29 mins  Unabridged Audiobook
# 2265  William Ditilio   3 hrs and 14 mins  Unabridged Audiobook
# 2266       Ron Butler   9 hrs and 33 mins  Unabridged Audiobook
# 2267       Karen Cass  10 hrs and 18 mins  Unabridged Audiobook
# 2268   Michelle Obama   19 hrs and 3 mins  Unabridged Audiobook
#
#                         Categories Rating  Total No. of Ratings    Price
# 0            Biographies & Memoirs      5                  47.0  $29.65
# 1        Science Fiction & Fantasy    4.5                  98.0  $24.95
# 2        Science Fiction & Fantasy   None                   NaN  $41.99
# 3                          History   None                   NaN  $29.65
# 4     Mystery, Thriller & Suspense    4.5                 108.0  $29.65
# ...                            ...    ...                   ...      ...
# 2264                       Erotica      5                 203.0  $14.95
# 2265             Health & Wellness      5                 203.0  $14.95
# 2266                       History    4.6                  70.0  $24.95
# 2267  Mystery, Thriller & Suspense    4.2                 141.0  $30.09
# 2268         Biographies & Memoirs    4.9              167195.0  $35.71
#
# [2269 rows x 11 columns]

# %% [markdown]
# เสร็จแล้วเหรอ ง่ายจัง ( ❛ ᴗ ❛ ) -- วิธีต่อไปง่ายกว่านี้อีก
#
# เราก็ได้ data table แรกของเรามาแล้ว

# %% [markdown]
# **ข้อสังเกต**
# ตัวเลขข้างหน้าสุดของ pandas ที่เป็น 0 ถึง (จำนวน rows - 1) ในที่นี้คือ 0 - 2268 เรียกว่า **index**
#
# index คือ สิ่งที่ pandas เอาไว้ใช้เก็บ key ในแต่ละ row เอาไว้ โดยถ้าไม่กำหนด index มาก็จะสร้างให้เหมือนในตัวอย่าง
#
# แต่ในที่นี้เรามี Book_ID ที่เป็นตัวเลย unique ประจำแถวอยู่แล้ว สามารถกำหนด index เป็น Book_ID ได้ เพื่อลดความซ้ำซ้อน

# %%
audible_data.set_index("Book_ID")
# Out:
#                                                 Book Title  \
# Book_ID
# 1                                      Bamboozled by Jesus
# 2                                       Sixth Realm Part 1
# 3                          Go Tell the Bees That I Am Gone
# 4                                   How the Word Is Passed
# 5                                      The Devil May Dance
# ...                                                    ...
# 2265                                            Kama Sutra
# 2266     Meditación Práctica para Principiantes [Prac...
# 2267                                             Forgotten
# 2268                                           The Missing
# 2269                                              Becoming
#
#                                              Book Subtitle        Book Author  \
# Book_ID
# 1            How God Tricked Me into the Life of My Dreams        Yvonne Orji
# 2         A LitRPG Fantasy Series (The Ten Realms, Book 6)  Michael Chatfield
# 3                                        Outlander, Book 9     Diana Gabaldon
# 4        A Reckoning with the History of Slavery Across...        Clint Smith
# 5                                                  A Novel        Jake Tapper
# ...                                                    ...                ...
# 2265     Become a Master of the Art of Love Making. Tan...         Eva Becker
# 2266     Una guía para principiantes para aliviar la an...        Taylor Knox
# 2267     The Untold Story of D-day's Black Heroes, at H...     Linda Hervieux
# 2268                                                  None       Daisy Pearce
# 2269                                                  None     Michelle Obama
#
#            Book Narrator       Audio Runtime        Audiobook_Type  \
# Book_ID
# 1            Yvonne Orji   6 hrs and 31 mins  Unabridged Audiobook
# 2         Neil Hellegers  13 hrs and 33 mins  Unabridged Audiobook
# 3          Davina Porter  27 hrs and 30 mins  Unabridged Audiobook
# 4            Clint Smith   10 hrs and 7 mins  Unabridged Audiobook
# 5            Rob Shapiro  10 hrs and 12 mins  Unabridged Audiobook
# ...                  ...                 ...                   ...
# 2265         ChasMandala   3 hrs and 29 mins  Unabridged Audiobook
# 2266     William Ditilio   3 hrs and 14 mins  Unabridged Audiobook
# 2267          Ron Butler   9 hrs and 33 mins  Unabridged Audiobook
# 2268          Karen Cass  10 hrs and 18 mins  Unabridged Audiobook
# 2269      Michelle Obama   19 hrs and 3 mins  Unabridged Audiobook
#
#                            Categories Rating  Total No. of Ratings    Price
# Book_ID
# 1               Biographies & Memoirs      5                  47.0  $29.65
# 2           Science Fiction & Fantasy    4.5                  98.0  $24.95
# 3           Science Fiction & Fantasy   None                   NaN  $41.99
# 4                             History   None                   NaN  $29.65
# 5        Mystery, Thriller & Suspense    4.5                 108.0  $29.65
# ...                               ...    ...                   ...      ...
# 2265                          Erotica      5                 203.0  $14.95
# 2266                Health & Wellness      5                 203.0  $14.95
# 2267                          History    4.6                  70.0  $24.95
# 2268     Mystery, Thriller & Suspense    4.2                 141.0  $30.09
# 2269            Biographies & Memoirs    4.9              167195.0  $35.71
#
# [2269 rows x 10 columns]

# %% [markdown]
# เท่านี้ก็สามารถ เอา Book_ID มาเป็น index ได้แล้ว
#
# ถ้าไม่อยาก set_index() ทีหลังก็ สามารถใส่ `index_col="Book_ID"` เพิ่มเข้าไปในบรรทัดที่สร้าง DataFrame เลยได้
# ```
# audible_data = pd.DataFrame(result), index_col="Book_ID"
# ```

# %% [markdown]
# ## อีกวิธีหนึ่งในการ query โดยใช้ Pandas สะดวกมาก ๆ

# %% [markdown]
# แต่ว่า เนื่องจากว่า table เรามีสอง table เรามาดูอีกวิธีหนึ่งที่สะดวกขึ้น โดยใช้ `read_sql()` ของ pandas

# %%
sql = "SELECT * FROM audible_transaction"
audible_transaction = pd.read_sql(sql, connection)
audible_transaction
# Out:
#                   timestamp   user_id  book_id                   country
# 0       2021-05-01 00:00:01  ad8eca41     1584                  Portugal
# 1       2021-05-01 00:00:03  561b26c1      829  United States of America
# 2       2021-05-01 00:00:04  81f149e5     1391                     Japan
# 3       2021-05-01 00:00:07  4f218413     1586                    Taiwan
# 4       2021-05-01 00:00:18  a4066781      300  United States of America
# ...                     ...       ...      ...                       ...
# 1998816 2021-07-31 23:59:47  72da1411      600                  Portugal
# 1998817 2021-07-31 23:59:48  620c27c8      462                Montenegro
# 1998818 2021-07-31 23:59:55  84fe88ab     1656  United States of America
# 1998819 2021-07-31 23:59:57  fd6cc4fc      522  United States of America
# 1998820 2021-07-31 23:59:59  9f4d5e3b      110  United States of America
#
# [1998821 rows x 4 columns]

# %% [markdown]
# โค้ดสวยขึ้นมาก ๆ สองบรรทัดจบ ( ❛ ᴗ ❛ )
# ถึงเวลาต้อง join ข้อมูลของสอง table

# %% [markdown]
# # Join table: audible_transaction & audible_data

# %% [markdown]
# ใน transaction dataframe เราจะไม่เห็นราคาและชื่อสินค้า ถ้าเราอยากรู้ว่าแต่ละ transaction มีจำนวนเงินเท่าไร จึงต้อง merge data รวมกับ dataframe ของ audible_data
#
# คีย์ที่ใช้ในการ merge คือ
# - audible_transaction: `book_id`
# - audible_data: `Book_ID`

# %%
transaction = audible_transaction.merge(audible_data, how="left", left_on="book_id", right_on="Book_ID")

# %% [markdown]
# ผลลัพธ์จากการ join จะได้เป็นแบบนี้

# %%
transaction
# Out:
#                   timestamp   user_id  book_id                   country  \
# 0       2021-05-01 00:00:01  ad8eca41     1584                  Portugal
# 1       2021-05-01 00:00:03  561b26c1      829  United States of America
# 2       2021-05-01 00:00:04  81f149e5     1391                     Japan
# 3       2021-05-01 00:00:07  4f218413     1586                    Taiwan
# 4       2021-05-01 00:00:18  a4066781      300  United States of America
# ...                     ...       ...      ...                       ...
# 1998816 2021-07-31 23:59:47  72da1411      600                  Portugal
# 1998817 2021-07-31 23:59:48  620c27c8      462                Montenegro
# 1998818 2021-07-31 23:59:55  84fe88ab     1656  United States of America
# 1998819 2021-07-31 23:59:57  fd6cc4fc      522  United States of America
# 1998820 2021-07-31 23:59:59  9f4d5e3b      110  United States of America
#
#          Book_ID                            Book Title  \
# 0           1584                          Sycamore Row
# 1            829      The 5 Love Languages of Children
# 2           1391                         The Guardians
# 3           1586                    How to Be a 3% Man
# 4            300  Napoleon Hill's Outwitting the Devil
# ...          ...                                   ...
# 1998816      600                  The Time of Contempt
# 1998817      462                             Endurance
# 1998818     1656               The Spy and the Traitor
# 1998819      522                           Lilac Girls
# 1998820      110                       Unfu*k Yourself
#
#                                         Book Subtitle        Book Author  \
# 0                                                None       John Grisham
# 1           The Secret to Loving Children Effectively       Gary Chapman
# 2                                             A Novel       John Grisham
# 3                                                None        Corey Wayne
# 4                   The Secret to Freedom and Success      Napoleon Hill
# ...                                               ...                ...
# 1998816                           The Witcher, Book 2  Andrzej Sapkowski
# 1998817                Shackleton's Incredible Voyage     Alfred Lansing
# 1998818  The Greatest Espionage Story of the Cold War      Ben Macintyre
# 1998819                                       A Novel  Martha Hall Kelly
# 1998820       Get Out of Your Head and into Your Life   Gary John Bishop
#
#               Book Narrator       Audio Runtime        Audiobook_Type  \
# 0              Michael Beck  20 hrs and 46 mins  Unabridged Audiobook
# 1               Chris Fabry   5 hrs and 48 mins  Unabridged Audiobook
# 2              Michael Beck  11 hrs and 50 mins  Unabridged Audiobook
# 3               Corey Wayne   7 hrs and 33 mins  Unabridged Audiobook
# 4           Dan John Miller   5 hrs and 51 mins  Unabridged Audiobook
# ...                     ...                 ...                   ...
# 1998816         Peter Kenny  11 hrs and 55 mins  Unabridged Audiobook
# 1998817       Simon Prebble  10 hrs and 20 mins  Unabridged Audiobook
# 1998818            John Lee  13 hrs and 20 mins  Unabridged Audiobook
# 1998819  Cassandra Campbell  17 hrs and 30 mins  Unabridged Audiobook
# 1998820    Gary John Bishop   3 hrs and 24 mins  Unabridged Audiobook
#
#                                               Categories Rating  \
# 0                           Mystery, Thriller & Suspense    4.6
# 1        Relationships, Parenting & Personal Development    4.8
# 2                           Mystery, Thriller & Suspense    4.6
# 3        Relationships, Parenting & Personal Development    4.8
# 4                                     Business & Careers    4.8
# ...                                                  ...    ...
# 1998816                        Science Fiction & Fantasy    4.7
# 1998817                                          History    4.7
# 1998818                            Biographies & Memoirs    4.8
# 1998819                             Literature & Fiction    4.7
# 1998820  Relationships, Parenting & Personal Development    4.6
#
#          Total No. of Ratings    Price
# 0                     25863.0  $35.00
# 1                      2441.0  $19.59
# 2                     26781.0  $31.50
# 3                     11459.0  $19.95
# 4                      9305.0  $17.49
# ...                       ...      ...
# 1998816               14344.0  $25.08
# 1998817               18764.0  $24.95
# 1998818                7150.0  $31.95
# 1998819               19401.0  $31.50
# 1998820               73022.0  $20.52
#
# [1998821 rows x 15 columns]

# %% [markdown]
# ตอนนี้เราได้ข้อมูล transaction มาแล้ว แต่ว่าข้อมูล price เป็น USD (แถมยังเป็น string ที่มี $ ด้วย)
#
# ในส่วนถัดไป เราจะมาอ่าน data จาก API แปลงค่าเงิน เพื่อแปลงเป็นเงินบาท ตาม rate ของแต่ละวันในอดีตกัน ʕ•́ᴥ•̀ʔ

# %% [markdown]
# ---
#
#
# # Get data from REST API

# %% [markdown]
# หลังจากต่อกับ Database ได้แล้ว ก็อ่าน data จาก REST API กัน

# %% [markdown]
# Package `requests` ใช้สำหรับการเรียกใช้ REST API
#
# (โดยปกติต้อง install package นี้เพิ่มเติม แต่ colab มี install ไว้อยู่แล้ว)
#
# วิธีการ install: `pip install requests`

# %%
import requests

# %% [markdown]
# ลองคลิกดูผลลัพธ์ผ่าน web browser ได้ [Currency conversion API](https://r2de2-workshop-vmftiryt6q-ts.a.run.app/usd_thb_conversion_rate)  การที่สามารถเปิดผ่าน web browser โดยตรงได้ มักจะเป็นการใช้งาน API แบบ **GET**
#
# ผลลัพธ์ที่ return กลับมาจะเป็นประเภท JSON
# จึงต้องใช้ package `json` (built-in) เพื่อโหลดข้อมูลเป็น dictionary หรือสามารถใช้ `.json()` ของ request เพื่อแปลงได้
#
# การที่เราสามารถยิง request และ output ออกมาได้เลยโดยที่ไม่ต้องสร้าง payload เพิ่ม ดังตัวอย่างนี้ เรียกว่า HTTP GET (ในกรณีอื่น ๆ สามารถเพิ่ม arguement หรือ query string เข้าไปใน URL ได้)
#
# ## Requests library
# สามารถศึกษาวิธีการสร้าง request และการใช้งาน package `requests` [ได้ที่นี่](https://requests.readthedocs.io/en/master/)

# %%
url = "https://r2de2-workshop-vmftiryt6q-ts.a.run.app/usd_thb_conversion_rate"
# TODO: ลองศึกษาวิธีการใช้งาน package requests จากลิ้งค์(ตัวแปร url) แล้วลองเขียนโค้ดเพื่อ call URL นี้
# ต้องการผลลัพธ์ให้อยู่ในรูปแบบของ dictionary ที่ชื่อว่า result_conversion_rate
r = requests.get(url)
result_conversion_rate = r.json()

# %%
result_conversion_rate
# Out:
# {'conversion_rate': {'2021-08-12': 33.084,
#   '2021-08-11': 33.145,
#   '2021-08-10': 33.46,
#   '2021-08-09': 33.464,
#   '2021-08-08': 33.395,
#   '2021-08-07': 33.422,
#   '2021-08-06': 33.45,
#   '2021-08-05': 33.263,
#   '2021-08-04': 33.137,
#   '2021-08-03': 33.022,
#   '2021-08-02': 32.957,
#   '2021-08-01': 32.895,
#   '2021-07-31': 32.887,
#   '2021-07-30': 32.887,
#   '2021-07-29': 32.87,
#   '2021-07-28': 32.82,
#   '2021-07-27': 32.937,
#   '2021-07-26': 32.929,
#   '2021-07-25': 32.94,
#   '2021-07-24': 32.963,
#   '2021-07-23': 32.928,
#   '2021-07-22': 32.887,
#   '2021-07-21': 32.857,
#   '2021-07-20': 32.829,
#   '2021-07-19': 32.854,
#   '2021-07-18': 32.807,
#   '2021-07-17': 32.795,
#   '2021-07-16': 32.783,
#   '2021-07-15': 32.686,
#   '2021-07-14': 32.605,
#   '2021-07-13': 32.654,
#   '2021-07-12': 32.664,
#   '2021-07-11': 32.506,
#   '2021-07-10': 32.482,
#   '2021-07-09': 32.512,
#   '2021-07-08': 32.534,
#   '2021-07-07': 32.334,
#   '2021-07-06': 32.271,
#   '2021-07-05': 32.112,
#   '2021-07-04': 32.136,
#   '2021-07-03': 32.125,
#   '2021-07-02': 32.126,
#   '2021-07-01': 32.073,
#   '2021-06-30': 32.029,
#   '2021-06-29': 32.108,
#   '2021-06-28': 31.918,
#   '2021-06-27': 31.785,
#   '2021-06-26': 31.816,
#   '2021-06-25': 31.816,
#   '2021-06-24': 31.898,
#   '2021-06-23': 31.825,
#   '2021-06-22': 31.681,
#   '2021-06-21': 31.617,
#   '2021-06-20': 31.461,
#   '2021-06-19': 31.437,
#   '2021-06-18': 31.439,
#   '2021-06-17': 31.422,
#   '2021-06-16': 31.297,
#   '2021-06-15': 31.162,
#   '2021-06-14': 31.117,
#   '2021-06-13': 31.077,
#   '2021-06-12': 31.074,
#   '2021-06-11': 31.092,
#   '2021-06-10': 31.14,
#   '2021-06-09': 31.167,
#   '2021-06-08': 31.202,
#   '2021-06-07': 31.176,
#   '2021-06-06': 31.133,
#   '2021-06-05': 31.125,
#   '2021-06-04': 31.125,
#   '2021-06-03': 31.209,
#   '2021-06-02': 31.108,
#   '2021-06-01': 31.169,
#   '2021-05-31': 31.193,
#   '2021-05-30': 31.238,
#   '2021-05-29': 31.252,
#   '2021-05-28': 31.257,
#   '2021-05-27': 31.297,
#   '2021-05-26': 31.281,
#   '2021-05-25': 31.328,
#   '2021-05-24': 31.323,
#   '2021-05-23': 31.37,
#   '2021-05-22': 31.361,
#   '2021-05-21': 31.361,
#   '2021-05-20': 31.378,
#   '2021-05-19': 31.413,
#   '2021-05-18': 31.42,
#   '2021-05-17': 31.492,
#   '2021-05-16': 31.365,
#   '2021-05-15': 31.33,
#   '2021-05-14': 31.33,
#   '2021-05-13': 31.344,
#   '2021-05-12': 31.304,
#   '2021-05-11': 31.158,
#   '2021-05-10': 31.107,
#   '2021-05-09': 31.033,
#   '2021-05-08': 31.042,
#   '2021-05-07': 31.042,
#   '2021-05-06': 31.226,
#   '2021-05-05': 31.13,
#   '2021-05-04': 31.188,
#   '2021-05-03': 31.132,
#   '2021-05-02': 31.122,
#   '2021-05-01': 31.14,
#   '2021-04-30': 31.139,
#   '2021-04-29': 31.197,
#   '2021-04-28': 31.344,
#   '2021-04-27': 31.355,
#   '2021-04-26': 31.427,
#   '2021-04-25': 31.421,
#   '2021-04-24': 31.411,
#   '2021-04-23': 31.412,
#   '2021-04-22': 31.378,
#   '2021-04-21': 31.3,
#   '2021-04-20': 31.281,
#   '2021-04-19': 31.203,
#   '2021-04-18': 31.226,
#   '2021-04-17': 31.204,
#   '2021-04-16': 31.203,
#   '2021-04-15': 31.165,
#   '2021-04-14': 31.329,
#   '2021-04-13': 31.496,
#   '2021-04-12': 31.482,
#   '2021-04-11': 31.462,
#   '2021-04-10': 31.454,
#   '2021-04-09': 31.451,
#   '2021-04-08': 31.433,
#   '2021-04-07': 31.387,
#   '2021-04-06': 31.288,
#   '2021-04-05': 31.342,
#   '2021-04-04': 31.244,
#   '2021-04-03': 31.256,
#   '2021-04-02': 31.29,
#   '2021-04-01': 31.194}}

# %% [markdown]
# มาเช็คประเภทข้อมูล

# %%
print(type(result_conversion_rate))
assert isinstance(result_conversion_rate, dict)
# Out:
# <class 'dict'>

# %% [markdown]
#  ## Convert to Pandas
#  แปลงกันอีกครั้งหนึ่ง ʕ•́ᴥ•̀ʔ

# %%
conversion_rate = pd.DataFrame(result_conversion_rate)

# %%
conversion_rate
# Out:
#             conversion_rate
# 2021-04-01           31.194
# 2021-04-02           31.290
# 2021-04-03           31.256
# 2021-04-04           31.244
# 2021-04-05           31.342
# ...                     ...
# 2021-08-08           33.395
# 2021-08-09           33.464
# 2021-08-10           33.460
# 2021-08-11           33.145
# 2021-08-12           33.084
#
# [134 rows x 1 columns]

# %% [markdown]
# แปลงจาก index เป็น column date ธรรมดาเพื่อความสะดวกในการ join กับ table transaction

# %%
conversion_rate = conversion_rate.reset_index().rename(columns={"index": "date"})
conversion_rate[:3]
# Out:
#          date  conversion_rate
# 0  2021-04-01           31.194
# 1  2021-04-02           31.290
# 2  2021-04-03           31.256

# %% [markdown]
# # Join the data

# %% [markdown]
# ในตอนนี้เราจะนำข้อมูลการซื้อขายและข้อมูล Rate การแปลงค่าเงิน เราจะรวมข้อมูลจากทั้งสอง Dataframe มารวมกัน
#
# เราจะนำข้อมูลจากทั้งสองมารวมกันผ่าน column date ใน transaction และ date ใน conversion_rate
#
# แต่ถ้าสังเกตดี ๆ แล้วจะพบว่า timestamp ใน retail จะเก็บข้อมูลในรูปแบบ timestamp ส่วน date ใน conversion_rate จะเก็บข้อมูลในรูปแบบ date (ที่เป็น string) เท่านั้น

# %%
transaction
# Out:
#                   timestamp   user_id  book_id                   country  \
# 0       2021-05-01 00:00:01  ad8eca41     1584                  Portugal
# 1       2021-05-01 00:00:03  561b26c1      829  United States of America
# 2       2021-05-01 00:00:04  81f149e5     1391                     Japan
# 3       2021-05-01 00:00:07  4f218413     1586                    Taiwan
# 4       2021-05-01 00:00:18  a4066781      300  United States of America
# ...                     ...       ...      ...                       ...
# 1998816 2021-07-31 23:59:47  72da1411      600                  Portugal
# 1998817 2021-07-31 23:59:48  620c27c8      462                Montenegro
# 1998818 2021-07-31 23:59:55  84fe88ab     1656  United States of America
# 1998819 2021-07-31 23:59:57  fd6cc4fc      522  United States of America
# 1998820 2021-07-31 23:59:59  9f4d5e3b      110  United States of America
#
#          Book_ID                            Book Title  \
# 0           1584                          Sycamore Row
# 1            829      The 5 Love Languages of Children
# 2           1391                         The Guardians
# 3           1586                    How to Be a 3% Man
# 4            300  Napoleon Hill's Outwitting the Devil
# ...          ...                                   ...
# 1998816      600                  The Time of Contempt
# 1998817      462                             Endurance
# 1998818     1656               The Spy and the Traitor
# 1998819      522                           Lilac Girls
# 1998820      110                       Unfu*k Yourself
#
#                                         Book Subtitle        Book Author  \
# 0                                                None       John Grisham
# 1           The Secret to Loving Children Effectively       Gary Chapman
# 2                                             A Novel       John Grisham
# 3                                                None        Corey Wayne
# 4                   The Secret to Freedom and Success      Napoleon Hill
# ...                                               ...                ...
# 1998816                           The Witcher, Book 2  Andrzej Sapkowski
# 1998817                Shackleton's Incredible Voyage     Alfred Lansing
# 1998818  The Greatest Espionage Story of the Cold War      Ben Macintyre
# 1998819                                       A Novel  Martha Hall Kelly
# 1998820       Get Out of Your Head and into Your Life   Gary John Bishop
#
#               Book Narrator       Audio Runtime        Audiobook_Type  \
# 0              Michael Beck  20 hrs and 46 mins  Unabridged Audiobook
# 1               Chris Fabry   5 hrs and 48 mins  Unabridged Audiobook
# 2              Michael Beck  11 hrs and 50 mins  Unabridged Audiobook
# 3               Corey Wayne   7 hrs and 33 mins  Unabridged Audiobook
# 4           Dan John Miller   5 hrs and 51 mins  Unabridged Audiobook
# ...                     ...                 ...                   ...
# 1998816         Peter Kenny  11 hrs and 55 mins  Unabridged Audiobook
# 1998817       Simon Prebble  10 hrs and 20 mins  Unabridged Audiobook
# 1998818            John Lee  13 hrs and 20 mins  Unabridged Audiobook
# 1998819  Cassandra Campbell  17 hrs and 30 mins  Unabridged Audiobook
# 1998820    Gary John Bishop   3 hrs and 24 mins  Unabridged Audiobook
#
#                                               Categories Rating  \
# 0                           Mystery, Thriller & Suspense    4.6
# 1        Relationships, Parenting & Personal Development    4.8
# 2                           Mystery, Thriller & Suspense    4.6
# 3        Relationships, Parenting & Personal Development    4.8
# 4                                     Business & Careers    4.8
# ...                                                  ...    ...
# 1998816                        Science Fiction & Fantasy    4.7
# 1998817                                          History    4.7
# 1998818                            Biographies & Memoirs    4.8
# 1998819                             Literature & Fiction    4.7
# 1998820  Relationships, Parenting & Personal Development    4.6
#
#          Total No. of Ratings    Price
# 0                     25863.0  $35.00
# 1                      2441.0  $19.59
# 2                     26781.0  $31.50
# 3                     11459.0  $19.95
# 4                      9305.0  $17.49
# ...                       ...      ...
# 1998816               14344.0  $25.08
# 1998817               18764.0  $24.95
# 1998818                7150.0  $31.95
# 1998819               19401.0  $31.50
# 1998820               73022.0  $20.52
#
# [1998821 rows x 15 columns]

# %%
# ก็อปปี้ column timestamp เก็บเอาไว้ใน column ใหม่ชื่อ date เพื่อที่จะแปลงวันที่เป็น date เพื่อที่จะสามารถนำมา join กับข้อมูลค่าเงินได้
transaction['date'] = transaction['timestamp']
transaction
# Out:
#                   timestamp   user_id  book_id                   country  \
# 0       2021-05-01 00:00:01  ad8eca41     1584                  Portugal
# 1       2021-05-01 00:00:03  561b26c1      829  United States of America
# 2       2021-05-01 00:00:04  81f149e5     1391                     Japan
# 3       2021-05-01 00:00:07  4f218413     1586                    Taiwan
# 4       2021-05-01 00:00:18  a4066781      300  United States of America
# ...                     ...       ...      ...                       ...
# 1998816 2021-07-31 23:59:47  72da1411      600                  Portugal
# 1998817 2021-07-31 23:59:48  620c27c8      462                Montenegro
# 1998818 2021-07-31 23:59:55  84fe88ab     1656  United States of America
# 1998819 2021-07-31 23:59:57  fd6cc4fc      522  United States of America
# 1998820 2021-07-31 23:59:59  9f4d5e3b      110  United States of America
#
#          Book_ID                            Book Title  \
# 0           1584                          Sycamore Row
# 1            829      The 5 Love Languages of Children
# 2           1391                         The Guardians
# 3           1586                    How to Be a 3% Man
# 4            300  Napoleon Hill's Outwitting the Devil
# ...          ...                                   ...
# 1998816      600                  The Time of Contempt
# 1998817      462                             Endurance
# 1998818     1656               The Spy and the Traitor
# 1998819      522                           Lilac Girls
# 1998820      110                       Unfu*k Yourself
#
#                                         Book Subtitle        Book Author  \
# 0                                                None       John Grisham
# 1           The Secret to Loving Children Effectively       Gary Chapman
# 2                                             A Novel       John Grisham
# 3                                                None        Corey Wayne
# 4                   The Secret to Freedom and Success      Napoleon Hill
# ...                                               ...                ...
# 1998816                           The Witcher, Book 2  Andrzej Sapkowski
# 1998817                Shackleton's Incredible Voyage     Alfred Lansing
# 1998818  The Greatest Espionage Story of the Cold War      Ben Macintyre
# 1998819                                       A Novel  Martha Hall Kelly
# 1998820       Get Out of Your Head and into Your Life   Gary John Bishop
#
#               Book Narrator       Audio Runtime        Audiobook_Type  \
# 0              Michael Beck  20 hrs and 46 mins  Unabridged Audiobook
# 1               Chris Fabry   5 hrs and 48 mins  Unabridged Audiobook
# 2              Michael Beck  11 hrs and 50 mins  Unabridged Audiobook
# 3               Corey Wayne   7 hrs and 33 mins  Unabridged Audiobook
# 4           Dan John Miller   5 hrs and 51 mins  Unabridged Audiobook
# ...                     ...                 ...                   ...
# 1998816         Peter Kenny  11 hrs and 55 mins  Unabridged Audiobook
# 1998817       Simon Prebble  10 hrs and 20 mins  Unabridged Audiobook
# 1998818            John Lee  13 hrs and 20 mins  Unabridged Audiobook
# 1998819  Cassandra Campbell  17 hrs and 30 mins  Unabridged Audiobook
# 1998820    Gary John Bishop   3 hrs and 24 mins  Unabridged Audiobook
#
#                                               Categories Rating  \
# 0                           Mystery, Thriller & Suspense    4.6
# 1        Relationships, Parenting & Personal Development    4.8
# 2                           Mystery, Thriller & Suspense    4.6
# 3        Relationships, Parenting & Personal Development    4.8
# 4                                     Business & Careers    4.8
# ...                                                  ...    ...
# 1998816                        Science Fiction & Fantasy    4.7
# 1998817                                          History    4.7
# 1998818                            Biographies & Memoirs    4.8
# 1998819                             Literature & Fiction    4.7
# 1998820  Relationships, Parenting & Personal Development    4.6
#
#          Total No. of Ratings    Price                date
# 0                     25863.0  $35.00  2021-05-01 00:00:01
# 1                      2441.0  $19.59  2021-05-01 00:00:03
# 2                     26781.0  $31.50  2021-05-01 00:00:04
# 3                     11459.0  $19.95  2021-05-01 00:00:07
# 4                      9305.0  $17.49  2021-05-01 00:00:18
# ...                       ...      ...                 ...
# 1998816               14344.0  $25.08  2021-07-31 23:59:47
# 1998817               18764.0  $24.95  2021-07-31 23:59:48
# 1998818                7150.0  $31.95  2021-07-31 23:59:55
# 1998819               19401.0  $31.50  2021-07-31 23:59:57
# 1998820               73022.0  $20.52  2021-07-31 23:59:59
#
# [1998821 rows x 16 columns]

# %%
# แปลงให้จาก timestamp เป็น date ในทั้ง 2 dataframe (transaction, conversion_rate)
transaction['date'] = pd.to_datetime(transaction['date']).dt.date
conversion_rate['date'] = pd.to_datetime(conversion_rate['date']).dt.date
transaction.head()
# Out:
#             timestamp   user_id  book_id                   country  Book_ID  \
# 0 2021-05-01 00:00:01  ad8eca41     1584                  Portugal     1584
# 1 2021-05-01 00:00:03  561b26c1      829  United States of America      829
# 2 2021-05-01 00:00:04  81f149e5     1391                     Japan     1391
# 3 2021-05-01 00:00:07  4f218413     1586                    Taiwan     1586
# 4 2021-05-01 00:00:18  a4066781      300  United States of America      300
#
#                              Book Title  \
# 0                          Sycamore Row
# 1      The 5 Love Languages of Children
# 2                         The Guardians
# 3                    How to Be a 3% Man
# 4  Napoleon Hill's Outwitting the Devil
#
#                                Book Subtitle    Book Author    Book Narrator  \
# 0                                       None   John Grisham     Michael Beck
# 1  The Secret to Loving Children Effectively   Gary Chapman      Chris Fabry
# 2                                    A Novel   John Grisham     Michael Beck
# 3                                       None    Corey Wayne      Corey Wayne
# 4          The Secret to Freedom and Success  Napoleon Hill  Dan John Miller
#
#         Audio Runtime        Audiobook_Type  \
# 0  20 hrs and 46 mins  Unabridged Audiobook
# 1   5 hrs and 48 mins  Unabridged Audiobook
# 2  11 hrs and 50 mins  Unabridged Audiobook
# 3   7 hrs and 33 mins  Unabridged Audiobook
# 4   5 hrs and 51 mins  Unabridged Audiobook
#
#                                         Categories Rating  \
# 0                     Mystery, Thriller & Suspense    4.6
# 1  Relationships, Parenting & Personal Development    4.8
# 2                     Mystery, Thriller & Suspense    4.6
# 3  Relationships, Parenting & Personal Development    4.8
# 4                               Business & Careers    4.8
#
#    Total No. of Ratings    Price        date
# 0               25863.0  $35.00   2021-05-01
# 1                2441.0  $19.59   2021-05-01
# 2               26781.0  $31.50   2021-05-01
# 3               11459.0  $19.95   2021-05-01
# 4                9305.0  $17.49   2021-05-01

# %%
# TODO: รวม 2 dataframe (transaction, conversion_rate) เข้าด้วยกันด้วยคำสั่ง merge
# ผลลัพธ์สุดท้ายตั้งชื่อว่า final_df
final_df = transaction.merge(conversion_rate, how="left", left_on="date", right_on="date")
final_df
# Out:
#                   timestamp   user_id  book_id                   country  \
# 0       2021-05-01 00:00:01  ad8eca41     1584                  Portugal
# 1       2021-05-01 00:00:03  561b26c1      829  United States of America
# 2       2021-05-01 00:00:04  81f149e5     1391                     Japan
# 3       2021-05-01 00:00:07  4f218413     1586                    Taiwan
# 4       2021-05-01 00:00:18  a4066781      300  United States of America
# ...                     ...       ...      ...                       ...
# 1998816 2021-07-31 23:59:47  72da1411      600                  Portugal
# 1998817 2021-07-31 23:59:48  620c27c8      462                Montenegro
# 1998818 2021-07-31 23:59:55  84fe88ab     1656  United States of America
# 1998819 2021-07-31 23:59:57  fd6cc4fc      522  United States of America
# 1998820 2021-07-31 23:59:59  9f4d5e3b      110  United States of America
#
#          Book_ID                            Book Title  \
# 0           1584                          Sycamore Row
# 1            829      The 5 Love Languages of Children
# 2           1391                         The Guardians
# 3           1586                    How to Be a 3% Man
# 4            300  Napoleon Hill's Outwitting the Devil
# ...          ...                                   ...
# 1998816      600                  The Time of Contempt
# 1998817      462                             Endurance
# 1998818     1656               The Spy and the Traitor
# 1998819      522                           Lilac Girls
# 1998820      110                       Unfu*k Yourself
#
#                                         Book Subtitle        Book Author  \
# 0                                                None       John Grisham
# 1           The Secret to Loving Children Effectively       Gary Chapman
# 2                                             A Novel       John Grisham
# 3                                                None        Corey Wayne
# 4                   The Secret to Freedom and Success      Napoleon Hill
# ...                                               ...                ...
# 1998816                           The Witcher, Book 2  Andrzej Sapkowski
# 1998817                Shackleton's Incredible Voyage     Alfred Lansing
# 1998818  The Greatest Espionage Story of the Cold War      Ben Macintyre
# 1998819                                       A Novel  Martha Hall Kelly
# 1998820       Get Out of Your Head and into Your Life   Gary John Bishop
#
#               Book Narrator       Audio Runtime        Audiobook_Type  \
# 0              Michael Beck  20 hrs and 46 mins  Unabridged Audiobook
# 1               Chris Fabry   5 hrs and 48 mins  Unabridged Audiobook
# 2              Michael Beck  11 hrs and 50 mins  Unabridged Audiobook
# 3               Corey Wayne   7 hrs and 33 mins  Unabridged Audiobook
# 4           Dan John Miller   5 hrs and 51 mins  Unabridged Audiobook
# ...                     ...                 ...                   ...
# 1998816         Peter Kenny  11 hrs and 55 mins  Unabridged Audiobook
# 1998817       Simon Prebble  10 hrs and 20 mins  Unabridged Audiobook
# 1998818            John Lee  13 hrs and 20 mins  Unabridged Audiobook
# 1998819  Cassandra Campbell  17 hrs and 30 mins  Unabridged Audiobook
# 1998820    Gary John Bishop   3 hrs and 24 mins  Unabridged Audiobook
#
#                                               Categories Rating  \
# 0                           Mystery, Thriller & Suspense    4.6
# 1        Relationships, Parenting & Personal Development    4.8
# 2                           Mystery, Thriller & Suspense    4.6
# 3        Relationships, Parenting & Personal Development    4.8
# 4                                     Business & Careers    4.8
# ...                                                  ...    ...
# 1998816                        Science Fiction & Fantasy    4.7
# 1998817                                          History    4.7
# 1998818                            Biographies & Memoirs    4.8
# 1998819                             Literature & Fiction    4.7
# 1998820  Relationships, Parenting & Personal Development    4.6
#
#          Total No. of Ratings    Price        date  conversion_rate
# 0                     25863.0  $35.00   2021-05-01           31.140
# 1                      2441.0  $19.59   2021-05-01           31.140
# 2                     26781.0  $31.50   2021-05-01           31.140
# 3                     11459.0  $19.95   2021-05-01           31.140
# 4                      9305.0  $17.49   2021-05-01           31.140
# ...                       ...      ...         ...              ...
# 1998816               14344.0  $25.08   2021-07-31           32.887
# 1998817               18764.0  $24.95   2021-07-31           32.887
# 1998818                7150.0  $31.95   2021-07-31           32.887
# 1998819               19401.0  $31.50   2021-07-31           32.887
# 1998820               73022.0  $20.52   2021-07-31           32.887
#
# [1998821 rows x 17 columns]

# %% [markdown]
# แต่ตอนนี้ column Price เรายังเป็น string (มีเครื่องหมาย $ อยู่ ต้องเอาออก)
# ในที่นี้จะใช้ function apply ของ DataFrame ภายใน apply จะเขียนในรูปแบบของ function หรือเป็น lambda function คือ function ที่สร้างขึ้นมา เพื่อประมวลผลในแต่ละแถว
#
# สุดท้าย แปลงประเภทตัวแปลง เป็น float เพื่อรองรับ จำนวนที่มีทศนิยม

# %%
final_df["Price"] = final_df.apply(lambda x: x["Price"].replace("$",""), axis=1)
final_df["Price"] = final_df["Price"].astype(float)

# %%
final_df
# Out:
#                   timestamp   user_id  book_id                   country  \
# 0       2021-05-01 00:00:01  ad8eca41     1584                  Portugal
# 1       2021-05-01 00:00:03  561b26c1      829  United States of America
# 2       2021-05-01 00:00:04  81f149e5     1391                     Japan
# 3       2021-05-01 00:00:07  4f218413     1586                    Taiwan
# 4       2021-05-01 00:00:18  a4066781      300  United States of America
# ...                     ...       ...      ...                       ...
# 1998816 2021-07-31 23:59:47  72da1411      600                  Portugal
# 1998817 2021-07-31 23:59:48  620c27c8      462                Montenegro
# 1998818 2021-07-31 23:59:55  84fe88ab     1656  United States of America
# 1998819 2021-07-31 23:59:57  fd6cc4fc      522  United States of America
# 1998820 2021-07-31 23:59:59  9f4d5e3b      110  United States of America
#
#          Book_ID                            Book Title  \
# 0           1584                          Sycamore Row
# 1            829      The 5 Love Languages of Children
# 2           1391                         The Guardians
# 3           1586                    How to Be a 3% Man
# 4            300  Napoleon Hill's Outwitting the Devil
# ...          ...                                   ...
# 1998816      600                  The Time of Contempt
# 1998817      462                             Endurance
# 1998818     1656               The Spy and the Traitor
# 1998819      522                           Lilac Girls
# 1998820      110                       Unfu*k Yourself
#
#                                         Book Subtitle        Book Author  \
# 0                                                None       John Grisham
# 1           The Secret to Loving Children Effectively       Gary Chapman
# 2                                             A Novel       John Grisham
# 3                                                None        Corey Wayne
# 4                   The Secret to Freedom and Success      Napoleon Hill
# ...                                               ...                ...
# 1998816                           The Witcher, Book 2  Andrzej Sapkowski
# 1998817                Shackleton's Incredible Voyage     Alfred Lansing
# 1998818  The Greatest Espionage Story of the Cold War      Ben Macintyre
# 1998819                                       A Novel  Martha Hall Kelly
# 1998820       Get Out of Your Head and into Your Life   Gary John Bishop
#
#               Book Narrator       Audio Runtime        Audiobook_Type  \
# 0              Michael Beck  20 hrs and 46 mins  Unabridged Audiobook
# 1               Chris Fabry   5 hrs and 48 mins  Unabridged Audiobook
# 2              Michael Beck  11 hrs and 50 mins  Unabridged Audiobook
# 3               Corey Wayne   7 hrs and 33 mins  Unabridged Audiobook
# 4           Dan John Miller   5 hrs and 51 mins  Unabridged Audiobook
# ...                     ...                 ...                   ...
# 1998816         Peter Kenny  11 hrs and 55 mins  Unabridged Audiobook
# 1998817       Simon Prebble  10 hrs and 20 mins  Unabridged Audiobook
# 1998818            John Lee  13 hrs and 20 mins  Unabridged Audiobook
# 1998819  Cassandra Campbell  17 hrs and 30 mins  Unabridged Audiobook
# 1998820    Gary John Bishop   3 hrs and 24 mins  Unabridged Audiobook
#
#                                               Categories Rating  \
# 0                           Mystery, Thriller & Suspense    4.6
# 1        Relationships, Parenting & Personal Development    4.8
# 2                           Mystery, Thriller & Suspense    4.6
# 3        Relationships, Parenting & Personal Development    4.8
# 4                                     Business & Careers    4.8
# ...                                                  ...    ...
# 1998816                        Science Fiction & Fantasy    4.7
# 1998817                                          History    4.7
# 1998818                            Biographies & Memoirs    4.8
# 1998819                             Literature & Fiction    4.7
# 1998820  Relationships, Parenting & Personal Development    4.6
#
#          Total No. of Ratings  Price        date  conversion_rate
# 0                     25863.0  35.00  2021-05-01           31.140
# 1                      2441.0  19.59  2021-05-01           31.140
# 2                     26781.0  31.50  2021-05-01           31.140
# 3                     11459.0  19.95  2021-05-01           31.140
# 4                      9305.0  17.49  2021-05-01           31.140
# ...                       ...    ...         ...              ...
# 1998816               14344.0  25.08  2021-07-31           32.887
# 1998817               18764.0  24.95  2021-07-31           32.887
# 1998818                7150.0  31.95  2021-07-31           32.887
# 1998819               19401.0  31.50  2021-07-31           32.887
# 1998820               73022.0  20.52  2021-07-31           32.887
#
# [1998821 rows x 17 columns]

# %%
final_df.dtypes
# Out:
# timestamp               datetime64[ns]
# user_id                         object
# book_id                          int64
# country                         object
# Book_ID                          int64
# Book Title                      object
# Book Subtitle                   object
# Book Author                     object
# Book Narrator                   object
# Audio Runtime                   object
# Audiobook_Type                  object
# Categories                      object
# Rating                          object
# Total No. of Ratings           float64
# Price                          float64
# date                            object
# conversion_rate                float64
# dtype: object

# %% [markdown]
# พอ join ข้อมูลได้แล้ว เราก็ มา คูณ currency conversion กัน (Price * convertsion_rate)

# %%
# TODO: เพิ่ม column 'THBPrice' ที่เกิดจาก column Price * conversion_rate
# Hint: ลองดู apply function ของ pandas
final_df['THBPrice'] = final_df['Price'] * final_df['conversion_rate']
final_df
# Out:
#                   timestamp   user_id  book_id                   country  \
# 0       2021-05-01 00:00:01  ad8eca41     1584                  Portugal
# 1       2021-05-01 00:00:03  561b26c1      829  United States of America
# 2       2021-05-01 00:00:04  81f149e5     1391                     Japan
# 3       2021-05-01 00:00:07  4f218413     1586                    Taiwan
# 4       2021-05-01 00:00:18  a4066781      300  United States of America
# ...                     ...       ...      ...                       ...
# 1998816 2021-07-31 23:59:47  72da1411      600                  Portugal
# 1998817 2021-07-31 23:59:48  620c27c8      462                Montenegro
# 1998818 2021-07-31 23:59:55  84fe88ab     1656  United States of America
# 1998819 2021-07-31 23:59:57  fd6cc4fc      522  United States of America
# 1998820 2021-07-31 23:59:59  9f4d5e3b      110  United States of America
#
#          Book_ID                            Book Title  \
# 0           1584                          Sycamore Row
# 1            829      The 5 Love Languages of Children
# 2           1391                         The Guardians
# 3           1586                    How to Be a 3% Man
# 4            300  Napoleon Hill's Outwitting the Devil
# ...          ...                                   ...
# 1998816      600                  The Time of Contempt
# 1998817      462                             Endurance
# 1998818     1656               The Spy and the Traitor
# 1998819      522                           Lilac Girls
# 1998820      110                       Unfu*k Yourself
#
#                                         Book Subtitle        Book Author  \
# 0                                                None       John Grisham
# 1           The Secret to Loving Children Effectively       Gary Chapman
# 2                                             A Novel       John Grisham
# 3                                                None        Corey Wayne
# 4                   The Secret to Freedom and Success      Napoleon Hill
# ...                                               ...                ...
# 1998816                           The Witcher, Book 2  Andrzej Sapkowski
# 1998817                Shackleton's Incredible Voyage     Alfred Lansing
# 1998818  The Greatest Espionage Story of the Cold War      Ben Macintyre
# 1998819                                       A Novel  Martha Hall Kelly
# 1998820       Get Out of Your Head and into Your Life   Gary John Bishop
#
#               Book Narrator       Audio Runtime        Audiobook_Type  \
# 0              Michael Beck  20 hrs and 46 mins  Unabridged Audiobook
# 1               Chris Fabry   5 hrs and 48 mins  Unabridged Audiobook
# 2              Michael Beck  11 hrs and 50 mins  Unabridged Audiobook
# 3               Corey Wayne   7 hrs and 33 mins  Unabridged Audiobook
# 4           Dan John Miller   5 hrs and 51 mins  Unabridged Audiobook
# ...                     ...                 ...                   ...
# 1998816         Peter Kenny  11 hrs and 55 mins  Unabridged Audiobook
# 1998817       Simon Prebble  10 hrs and 20 mins  Unabridged Audiobook
# 1998818            John Lee  13 hrs and 20 mins  Unabridged Audiobook
# 1998819  Cassandra Campbell  17 hrs and 30 mins  Unabridged Audiobook
# 1998820    Gary John Bishop   3 hrs and 24 mins  Unabridged Audiobook
#
#                                               Categories Rating  \
# 0                           Mystery, Thriller & Suspense    4.6
# 1        Relationships, Parenting & Personal Development    4.8
# 2                           Mystery, Thriller & Suspense    4.6
# 3        Relationships, Parenting & Personal Development    4.8
# 4                                     Business & Careers    4.8
# ...                                                  ...    ...
# 1998816                        Science Fiction & Fantasy    4.7
# 1998817                                          History    4.7
# 1998818                            Biographies & Memoirs    4.8
# 1998819                             Literature & Fiction    4.7
# 1998820  Relationships, Parenting & Personal Development    4.6
#
#          Total No. of Ratings  Price        date  conversion_rate    THBPrice
# 0                     25863.0  35.00  2021-05-01           31.140  1089.90000
# 1                      2441.0  19.59  2021-05-01           31.140   610.03260
# 2                     26781.0  31.50  2021-05-01           31.140   980.91000
# 3                     11459.0  19.95  2021-05-01           31.140   621.24300
# 4                      9305.0  17.49  2021-05-01           31.140   544.63860
# ...                       ...    ...         ...              ...         ...
# 1998816               14344.0  25.08  2021-07-31           32.887   824.80596
# 1998817               18764.0  24.95  2021-07-31           32.887   820.53065
# 1998818                7150.0  31.95  2021-07-31           32.887  1050.73965
# 1998819               19401.0  31.50  2021-07-31           32.887  1035.94050
# 1998820               73022.0  20.52  2021-07-31           32.887   674.84124
#
# [1998821 rows x 18 columns]

# %% [markdown]
# อีกวิธีหนึ่ง

# %%
def convert_rate(price, rate):
  return price * rate

final_df["THBPrice1"] = final_df.apply(lambda x: x["Price"] * x["conversion_rate"], axis=1)
final_df["THBPrice1"]
final_df["THBPrice2"] = final_df.apply(lambda x: convert_rate(x["Price"], x["conversion_rate"]), axis=1)
final_df["THBPrice2"]
# Out:
# 0          1089.90000
# 1           610.03260
# 2           980.91000
# 3           621.24300
# 4           544.63860
#               ...
# 1998816     824.80596
# 1998817     820.53065
# 1998818    1050.73965
# 1998819    1035.94050
# 1998820     674.84124
# Name: THBPrice2, Length: 1998821, dtype: float64

# %%
final_df
# Out:
#                   timestamp   user_id  book_id                   country  \
# 0       2021-05-01 00:00:01  ad8eca41     1584                  Portugal
# 1       2021-05-01 00:00:03  561b26c1      829  United States of America
# 2       2021-05-01 00:00:04  81f149e5     1391                     Japan
# 3       2021-05-01 00:00:07  4f218413     1586                    Taiwan
# 4       2021-05-01 00:00:18  a4066781      300  United States of America
# ...                     ...       ...      ...                       ...
# 1998816 2021-07-31 23:59:47  72da1411      600                  Portugal
# 1998817 2021-07-31 23:59:48  620c27c8      462                Montenegro
# 1998818 2021-07-31 23:59:55  84fe88ab     1656  United States of America
# 1998819 2021-07-31 23:59:57  fd6cc4fc      522  United States of America
# 1998820 2021-07-31 23:59:59  9f4d5e3b      110  United States of America
#
#          Book_ID                            Book Title  \
# 0           1584                          Sycamore Row
# 1            829      The 5 Love Languages of Children
# 2           1391                         The Guardians
# 3           1586                    How to Be a 3% Man
# 4            300  Napoleon Hill's Outwitting the Devil
# ...          ...                                   ...
# 1998816      600                  The Time of Contempt
# 1998817      462                             Endurance
# 1998818     1656               The Spy and the Traitor
# 1998819      522                           Lilac Girls
# 1998820      110                       Unfu*k Yourself
#
#                                         Book Subtitle        Book Author  \
# 0                                                None       John Grisham
# 1           The Secret to Loving Children Effectively       Gary Chapman
# 2                                             A Novel       John Grisham
# 3                                                None        Corey Wayne
# 4                   The Secret to Freedom and Success      Napoleon Hill
# ...                                               ...                ...
# 1998816                           The Witcher, Book 2  Andrzej Sapkowski
# 1998817                Shackleton's Incredible Voyage     Alfred Lansing
# 1998818  The Greatest Espionage Story of the Cold War      Ben Macintyre
# 1998819                                       A Novel  Martha Hall Kelly
# 1998820       Get Out of Your Head and into Your Life   Gary John Bishop
#
#               Book Narrator       Audio Runtime        Audiobook_Type  \
# 0              Michael Beck  20 hrs and 46 mins  Unabridged Audiobook
# 1               Chris Fabry   5 hrs and 48 mins  Unabridged Audiobook
# 2              Michael Beck  11 hrs and 50 mins  Unabridged Audiobook
# 3               Corey Wayne   7 hrs and 33 mins  Unabridged Audiobook
# 4           Dan John Miller   5 hrs and 51 mins  Unabridged Audiobook
# ...                     ...                 ...                   ...
# 1998816         Peter Kenny  11 hrs and 55 mins  Unabridged Audiobook
# 1998817       Simon Prebble  10 hrs and 20 mins  Unabridged Audiobook
# 1998818            John Lee  13 hrs and 20 mins  Unabridged Audiobook
# 1998819  Cassandra Campbell  17 hrs and 30 mins  Unabridged Audiobook
# 1998820    Gary John Bishop   3 hrs and 24 mins  Unabridged Audiobook
#
#                                               Categories Rating  \
# 0                           Mystery, Thriller & Suspense    4.6
# 1        Relationships, Parenting & Personal Development    4.8
# 2                           Mystery, Thriller & Suspense    4.6
# 3        Relationships, Parenting & Personal Development    4.8
# 4                                     Business & Careers    4.8
# ...                                                  ...    ...
# 1998816                        Science Fiction & Fantasy    4.7
# 1998817                                          History    4.7
# 1998818                            Biographies & Memoirs    4.8
# 1998819                             Literature & Fiction    4.7
# 1998820  Relationships, Parenting & Personal Development    4.6
#
#          Total No. of Ratings  Price        date  conversion_rate    THBPrice  \
# 0                     25863.0  35.00  2021-05-01           31.140  1089.90000
# 1                      2441.0  19.59  2021-05-01           31.140   610.03260
# 2                     26781.0  31.50  2021-05-01           31.140   980.91000
# 3                     11459.0  19.95  2021-05-01           31.140   621.24300
# 4                      9305.0  17.49  2021-05-01           31.140   544.63860
# ...                       ...    ...         ...              ...         ...
# 1998816               14344.0  25.08  2021-07-31           32.887   824.80596
# 1998817               18764.0  24.95  2021-07-31           32.887   820.53065
# 1998818                7150.0  31.95  2021-07-31           32.887  1050.73965
# 1998819               19401.0  31.50  2021-07-31           32.887  1035.94050
# 1998820               73022.0  20.52  2021-07-31           32.887   674.84124
#
#           THBPrice2   THBPrice1
# 0        1089.90000  1089.90000
# 1         610.03260   610.03260
# 2         980.91000   980.91000
# 3         621.24300   621.24300
# 4         544.63860   544.63860
# ...             ...         ...
# 1998816   824.80596   824.80596
# 1998817   820.53065   820.53065
# 1998818  1050.73965  1050.73965
# 1998819  1035.94050  1035.94050
# 1998820   674.84124   674.84124
#
# [1998821 rows x 20 columns]

# %% [markdown]
# สามารถ drop column ที่ไม่จำเป็นต้องใช้ได้ เช่น date ที่ซ้ำซ้อนกับ timestamp
#
# axis = 1 หมายถึง drop column (ถ้า axis=0 จะใช้ drop row ได้)

# %%
final_df = final_df.drop("date", axis=1)

# %% [markdown]
# ## Save to CSV

# %% [markdown]
# เซฟ final_df เป็นไฟล์ csv
# โดยปกติ pandas จะเซฟ index (0,1,2,3) ติดมาให้ด้วย ถ้าไม่ต้องการจะต้องใส่ `index=False`

# %%
# TODO: save "to csv" file
final_df.to_csv("output.csv" , index=False)

# %% [markdown]
# <== กด ไอคอนรูป ไฟล์ image.pngที่แถบด้านซ้ายเพื่อดูไฟล์ที่เซฟอยู่ใน directory :)
#
#
#
# ลองกด Download มาดูได้

# %% [markdown]
# หรือสามารถเปิดดูไฟล์ด้วย bash command `head` ได้ด้วย

# %%
# !head output.csv
# Out:
# timestamp,user_id,book_id,country,Book_ID,Book Title,Book Subtitle,Book Author,Book Narrator,Audio Runtime,Audiobook_Type,Categories,Rating,Total No. of Ratings,Price,conversion_rate,THBPrice,THBPrice2,THBPrice1
# 2021-05-01 00:00:01,ad8eca41,1584,Portugal,1584,Sycamore Row,,John Grisham,Michael Beck,20 hrs and 46 mins,Unabridged Audiobook,"Mystery, Thriller & Suspense",4.6,25863.0,35.0,31.14,1089.9,1089.9,1089.9
# 2021-05-01 00:00:03,561b26c1,829,United States of America,829,The 5 Love Languages of Children,The Secret to Loving Children Effectively,Gary Chapman,Chris Fabry,5 hrs and 48 mins,Unabridged Audiobook,"Relationships, Parenting & Personal Development",4.8,2441.0,19.59,31.14,610.0326,610.0326,610.0326
# 2021-05-01 00:00:04,81f149e5,1391,Japan,1391,The Guardians,A Novel,John Grisham,Michael Beck,11 hrs and 50 mins,Unabridged Audiobook,"Mystery, Thriller & Suspense",4.6,26781.0,31.5,31.14,980.91,980.91,980.91
# 2021-05-01 00:00:07,4f218413,1586,Taiwan,1586,How to Be a 3% Man,,Corey Wayne,Corey Wayne,7 hrs and 33 mins,Unabridged Audiobook,"Relationships, Parenting & Personal Development",4.8,11459.0,19.95,31.14,621.2429999999999,621.2429999999999,621.2429999999999
# 2021-05-01 00:00:18,a4066781,300,United States of America,300,Napoleon Hill's Outwitting the Devil,The Secret to Freedom and Success,Napoleon Hill,Dan John Miller,5 hrs and 51 mins,Unabridged Audiobook,Business & Careers,4.8,9305.0,17.49,31.14,544.6386,544.6386,544.6386
# 2021-05-01 00:00:21,bbbd603a,1377,United States of America,1377,The Institute,A Novel,Stephen King,Santino Fontana,18 hrs and 59 mins,Unabridged Audiobook,Literature & Fiction,4.6,35443.0,34.99,31.14,1089.5886,1089.5886,1089.5886
# 2021-05-01 00:00:22,f636754b,342,Canada,342,A Clash of Kings,"A Song of Ice and Fire, Book 2",George R.R. Martin,Roy Dotrice,37 hrs and 12 mins,Unabridged Audiobook,Science Fiction & Fantasy,4.8,79031.0,63.0,31.14,1961.82,1961.82,1961.82
# 2021-05-01 00:00:26,0eea4bbd,1600,United States of America,1600,Exile,"Legend of Drizzt: Dark Elf Trilogy, Book 2",R. A. Salvatore,Victor Bevine,10 hrs and 42 mins,Unabridged Audiobook,Science Fiction & Fantasy,4.7,9241.0,24.95,31.14,776.943,776.943,776.943
# 2021-05-01 00:00:26,30b900d5,1556,Algeria,1556,Arcanum Unbounded: The Cosmere Collection,,Brandon Sanderson,Michael Kramer,22 hrs and 31 mins,Unabridged Audiobook,Literature & Fiction,4.8,14108.0,48.99,31.14,1525.5486,1525.5486,1525.5486

# %%
print("== End of Workshop 1 ʕ•́ᴥ•̀ʔっ♡ ==")
# Out:
# == End of Workshop 1 ʕ•́ᴥ•̀ʔっ♡ ==

# %% [markdown]
# # Bonus: การเก็บตัวแปร หรือ password ไว้ใน env ไฟล์

# %% [markdown]
# ## การสร้างไฟล์ .env จากใน colab
# สามารถใช้ `%%writefile ชื่อไฟล์` ตามด้วยเนื้อหาในไฟล์
#
# หมายเหตุ: ในชีวิตจริง .env จะไม่ได้ถูกเขียนขึ้นจากในโค้ด แต่จะแชร์กันแค่ภายในทีม

# %%
# %%writefile .env
# MYSQL_HOST='ใส่ host ที่นี่'
# MYSQL_PORT= 3306
# MYSQL_USER = 'ใส่ user ที่นี่'
# MYSQL_PASSWORD = 'ความลับ'
# MYSQL_DB = 'ใส่ชื่อ db ที่นี่'
# MYSQL_CHARSET = 'utf8mb4'
# Out:
# Overwriting .env

# %% [markdown]
# อ่านเชื่อไฟล์ด้วย bash command `cat ชื่อไฟล์`

# %%
# !cat .env
# Out:
# MYSQL_HOST='ใส่ host ที่นี่'
# MYSQL_PORT= 3306
# MYSQL_USER = 'ใส่ user ที่นี่'
# MYSQL_PASSWORD = 'ความลับ'
# MYSQL_DB = 'ใส่ชื่อ db ที่นี่'
# MYSQL_CHARSET = 'utf8mb4'

# %% [markdown]
# ## การอ่านตัวแปร .env จากไฟล์ง่าย ๆ ด้วย python-dotenv
# เริ่มจาก install แพ็คเกจ python-dotenv ก่อน

# %%
# !pip install python-dotenv
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.7/dist-packages (0.21.0)

# %% [markdown]
# เรียกใช้งานและอ่านตัวแปรจาก .env เข้ามา

# %%
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# คำสั่ง `load_dotenv()` เป็นการอ่านไฟล์ .env เข้ามาในตัวแปร environment variable แล้วใช้ `os.getenv()` เพื่ออ่านค่าของ variable แต่ละตัวอีกที

# %%
class Config:
  MYSQL_HOST = os.getenv("MYSQL_HOST")
  MYSQL_PORT = int(os.getenv("MYSQL_PORT"))
  MYSQL_USER = os.getenv("MYSQL_USER")
  MYSQL_PASSWORD = os.getenv("MYSQL_PASSWORD")
  MYSQL_DB = os.getenv("MYSQL_DB")
  MYSQL_CHARSET = os.getenv("MYSQL_CHARSET")

# %%
Config.MYSQL_USER
# Out:
# 'ใส่ user ที่นี่'

# %% [markdown]
# **ข้อควรระวัง** : ทุกครั้งที่มีการอ่าน `os.getenv` ตัวแปรที่มาจาก environment variable จะถูกอ่านมาเป็น string เสมอ ถ้าเป็นประเภทอื่นต้องนำมาแปลงค่าก่อนทุกครั้ง เช่น ใช้ `int()`

# %%
os.getenv("MYSQL_PORT")
# Out:
# '3306'

# %%
int(os.getenv("MYSQL_PORT"))
# Out:
# 3306

# %%
print("== End of Workshop 1 ʕ•́ᴥ•̀ʔっ♡ จบจริง ๆ แล้ว ==")
